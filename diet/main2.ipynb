# %%
import pandas as pd
import numpy as np

# Load the dataset
data = pd.read_csv('nutrition.csv')

# Function to calculate BMR and TDEE
def calculate_caloric_intake(age, gender, height, weight, activity_level, disease):
    if gender.lower() == 'male':
        bmr = 88.362 + (13.397 * weight) + (4.799 * height) - (5.677 * age)
    else:
        bmr = 447.593 + (9.247 * weight) + (3.098 * height) - (4.330 * age)
    
    if activity_level == 'sedentary':
        tdee = bmr * 1.2
    elif activity_level == 'lightly active':
        tdee = bmr * 1.375
    elif activity_level == 'moderately active':
        tdee = bmr * 1.55
    elif activity_level == 'very active':
        tdee = bmr * 1.725
    else:
        tdee = bmr * 1.9

    return tdee

# Function to generate meal plan
def generate_meal_plan(tdee):
    # Filter food items based on desired criteria (e.g., calories, macronutrients)
    breakfast_items = data.sample(n=5)  # Sample top 5 breakfast choices
    lunch_items = data.sample(n=5)      # Sample top 5 lunch choices
    dinner_items = data.sample(n=5)     # Sample top 5 dinner choices
    
    # Function to select random food item from given items
    def select_food_items(items, calories):
        selected_items = items[items['calories'] <= calories]
        
        if selected_items.empty:
            return None
        else:
            selected_food_names = selected_items['name'].tolist()
            numbered_food_names = '\n'.join([f"{i+1}. {name}" for i, name in enumerate(selected_food_names)])
            return numbered_food_names

    # Divide daily caloric intake into three meals
    breakfast_calories = tdee * 0.3
    lunch_calories = tdee * 0.4
    dinner_calories = tdee * 0.3
    
    # Select food items for each meal
    breakfast = select_food_items(breakfast_items, breakfast_calories)
    lunch = select_food_items(lunch_items, lunch_calories)
    dinner = select_food_items(dinner_items, dinner_calories)
    
    return breakfast, lunch, dinner

# Example user inputs
age = 25
gender = 'male'
height = 175
weight = 70
activity_level = 'moderately active'
disease = 'none'

# Calculate required caloric intake
tdee = calculate_caloric_intake(age, gender, height, weight, activity_level, disease)

# Generate meal plan
breakfast, lunch, dinner = generate_meal_plan(tdee)

print("Top 5 Breakfast Choices:")
print(breakfast)
print("\nTop 5 Lunch Choices:")
print(lunch)
print("\nTop 5 Dinner Choices:")
print(dinner)
# Out:
# Top 5 Breakfast Choices:
# 1. Beef, pan-broiled, cooked, patty, 85% lean meat / 15% fat, ground
# 2. Bread, wheat
# 3. Turkey, roasted, cooked, from dark meat, from retail parts, skin
# 4. CAMPBELL'S, Organic Tomato juice
# 5. Pork, unheated, separable lean only, whole, ham, cured
#
# Top 5 Lunch Choices:
# 1. Snacks, cheese-flavor, puffs or twists, extruded, corn-based
# 2. Corn, unprepared, kernels on cob, frozen, white, sweet
# 3. Cheese, neufchatel
# 4. Beef, fast fried, cooked, knuckle, imported, New Zealand
# 5. Pie, prepared from recipe, vanilla cream
#
# Top 5 Dinner Choices:
# 1. MURRAY, Vanilla Wafer
# 2. Beef, grilled, cooked, select, trimmed to 0" fat, separable lean only, boneless, chuck eye steak
# 3. Restaurant, breaded and fried, shrimp, family style
# 4. Bread, toasted (includes sourdough), french or vienna
# 5. Veal, raw, separable lean and fat, loin

# %%
import pymongo

# Connect to MongoDB (adjust connection string and database name as needed)
client = pymongo.MongoClient("mongodb+srv://prathamdoshi42:vJdq24J7ZfTqfvRR@cluster0.vsfywjg.mongodb.net/")
db = client["nutrition"]  # Replace with your database name
collection = db["values"]  # Replace with your collection name

# %%
# Find all documents in the collection
cursor = collection.find()

# Iterate over the cursor to print each document
for document in cursor:
    print(document)
# Out:
# {'_id': ObjectId('667fe0f54d235c4a24913318'), 'NDB_No': 1001, 'Shrt_Desc': 'BUTTER,WITH SALT', 'Water_(g)': 15.87, 'Energ_Kcal': 717, 'Protein_(g)': 0.85, 'Carbohydrt_(g)': 0.06}
# {'_id': ObjectId('667fe0f54d235c4a24913319'), 'NDB_No': 1002, 'Shrt_Desc': 'BUTTER,WHIPPED,W/ SALT', 'Water_(g)': 16.72, 'Energ_Kcal': 718, 'Protein_(g)': 0.49, 'Carbohydrt_(g)': 2.87}
# {'_id': ObjectId('667fe0f54d235c4a2491331a'), 'NDB_No': 1003, 'Shrt_Desc': 'BUTTER OIL,ANHYDROUS', 'Water_(g)': 0.24, 'Energ_Kcal': 876, 'Protein_(g)': 0.28, 'Carbohydrt_(g)': 0.0}
# {'_id': ObjectId('667fe0f54d235c4a2491331b'), 'NDB_No': 1004, 'Shrt_Desc': 'CHEESE,BLUE', 'Water_(g)': 42.41, 'Energ_Kcal': 353, 'Protein_(g)': 21.4, 'Carbohydrt_(g)': 2.34}
# {'_id': ObjectId('667fe0f54d235c4a2491331c'), 'NDB_No': 1005, 'Shrt_Desc': 'CHEESE,BRICK', 'Water_(g)': 41.11, 'Energ_Kcal': 371, 'Protein_(g)': 23.24, 'Carbohydrt_(g)': 2.79}
# {'_id': ObjectId('667fe0f54d235c4a2491331d'), 'NDB_No': 1006, 'Shrt_Desc': 'CHEESE,BRIE', 'Water_(g)': 48.42, 'Energ_Kcal': 334, 'Protein_(g)': 20.75, 'Carbohydrt_(g)': 0.45}
# {'_id': ObjectId('667fe0f54d235c4a2491331e'), 'NDB_No': 1007, 'Shrt_Desc': 'CHEESE,CAMEMBERT', 'Water_(g)': 51.8, 'Energ_Kcal': 300, 'Protein_(g)': 19.8, 'Carbohydrt_(g)': 0.46}
# {'_id': ObjectId('667fe0f54d235c4a2491331f'), 'NDB_No': 1008, 'Shrt_Desc': 'CHEESE,CARAWAY', 'Water_(g)': 39.28, 'Energ_Kcal': 376, 'Protein_(g)': 25.18, 'Carbohydrt_(g)': 3.06}
# {'_id': ObjectId('667fe0f54d235c4a24913320'), 'NDB_No': 1009, 'Shrt_Desc': 'CHEESE,CHEDDAR', 'Water_(g)': 37.02, 'Energ_Kcal': 404, 'Protein_(g)': 22.87, 'Carbohydrt_(g)': 3.09}
# {'_id': ObjectId('667fe0f54d235c4a24913321'), 'NDB_No': 1010, 'Shrt_Desc': 'CHEESE,CHESHIRE', 'Water_(g)': 37.65, 'Energ_Kcal': 387, 'Protein_(g)': 23.37, 'Carbohydrt_(g)': 4.78}
# {'_id': ObjectId('667fe0f54d235c4a24913322'), 'NDB_No': 1011, 'Shrt_Desc': 'CHEESE,COLBY', 'Water_(g)': 38.2, 'Energ_Kcal': 394, 'Protein_(g)': 23.76, 'Carbohydrt_(g)': 2.57}
# {'_id': ObjectId('667fe0f54d235c4a24913323'), 'NDB_No': 1012, 'Shrt_Desc': 'CHEESE,COTTAGE,CRMD,LRG OR SML CURD', 'Water_(g)': 79.79, 'Energ_Kcal': 98, 'Protein_(g)': 11.12, 'Carbohydrt_(g)': 3.38}
# {'_id': ObjectId('667fe0f54d235c4a24913324'), 'NDB_No': 1013, 'Shrt_Desc': 'CHEESE,COTTAGE,CRMD,W/FRUIT', 'Water_(g)': 79.64, 'Energ_Kcal': 97, 'Protein_(g)': 10.69, 'Carbohydrt_(g)': 4.61}
# {'_id': ObjectId('667fe0f54d235c4a24913325'), 'NDB_No': 1014, 'Shrt_Desc': 'CHEESE,COTTAGE,NONFAT,UNCRMD,DRY,LRG OR SML CURD', 'Water_(g)': 81.01, 'Energ_Kcal': 72, 'Protein_(g)': 10.34, 'Carbohydrt_(g)': 6.66}
# {'_id': ObjectId('667fe0f54d235c4a24913326'), 'NDB_No': 1015, 'Shrt_Desc': 'CHEESE,COTTAGE,LOWFAT,2% MILKFAT', 'Water_(g)': 81.24, 'Energ_Kcal': 81, 'Protein_(g)': 10.45, 'Carbohydrt_(g)': 4.76}
# {'_id': ObjectId('667fe0f54d235c4a24913327'), 'NDB_No': 1016, 'Shrt_Desc': 'CHEESE,COTTAGE,LOWFAT,1% MILKFAT', 'Water_(g)': 82.48, 'Energ_Kcal': 72, 'Protein_(g)': 12.39, 'Carbohydrt_(g)': 2.72}
# {'_id': ObjectId('667fe0f54d235c4a24913328'), 'NDB_No': 1017, 'Shrt_Desc': 'CHEESE,CREAM', 'Water_(g)': 52.62, 'Energ_Kcal': 350, 'Protein_(g)': 6.15, 'Carbohydrt_(g)': 5.52}
# {'_id': ObjectId('667fe0f54d235c4a24913329'), 'NDB_No': 1018, 'Shrt_Desc': 'CHEESE,EDAM', 'Water_(g)': 41.56, 'Energ_Kcal': 357, 'Protein_(g)': 24.99, 'Carbohydrt_(g)': 1.43}
# {'_id': ObjectId('667fe0f54d235c4a2491332a'), 'NDB_No': 1019, 'Shrt_Desc': 'CHEESE,FETA', 'Water_(g)': 55.22, 'Energ_Kcal': 264, 'Protein_(g)': 14.21, 'Carbohydrt_(g)': 4.09}
# {'_id': ObjectId('667fe0f54d235c4a2491332b'), 'NDB_No': 1020, 'Shrt_Desc': 'CHEESE,FONTINA', 'Water_(g)': 37.92, 'Energ_Kcal': 389, 'Protein_(g)': 25.6, 'Carbohydrt_(g)': 1.55}
# {'_id': ObjectId('667fe0f54d235c4a2491332c'), 'NDB_No': 1021, 'Shrt_Desc': 'CHEESE,GJETOST', 'Water_(g)': 13.44, 'Energ_Kcal': 466, 'Protein_(g)': 9.65, 'Carbohydrt_(g)': 42.65}
# {'_id': ObjectId('667fe0f54d235c4a2491332d'), 'NDB_No': 1022, 'Shrt_Desc': 'CHEESE,GOUDA', 'Water_(g)': 41.46, 'Energ_Kcal': 356, 'Protein_(g)': 24.94, 'Carbohydrt_(g)': 2.22}
# {'_id': ObjectId('667fe0f54d235c4a2491332e'), 'NDB_No': 1023, 'Shrt_Desc': 'CHEESE,GRUYERE', 'Water_(g)': 33.19, 'Energ_Kcal': 413, 'Protein_(g)': 29.81, 'Carbohydrt_(g)': 0.36}
# {'_id': ObjectId('667fe0f54d235c4a2491332f'), 'NDB_No': 1024, 'Shrt_Desc': 'CHEESE,LIMBURGER', 'Water_(g)': 48.42, 'Energ_Kcal': 327, 'Protein_(g)': 20.05, 'Carbohydrt_(g)': 0.49}
# {'_id': ObjectId('667fe0f54d235c4a24913330'), 'NDB_No': 1025, 'Shrt_Desc': 'CHEESE,MONTEREY', 'Water_(g)': 41.01, 'Energ_Kcal': 373, 'Protein_(g)': 24.48, 'Carbohydrt_(g)': 0.68}
# {'_id': ObjectId('667fe0f54d235c4a24913331'), 'NDB_No': 1026, 'Shrt_Desc': 'CHEESE,MOZZARELLA,WHL MILK', 'Water_(g)': 50.01, 'Energ_Kcal': 300, 'Protein_(g)': 22.17, 'Carbohydrt_(g)': 2.19}
# {'_id': ObjectId('667fe0f54d235c4a24913332'), 'NDB_No': 1027, 'Shrt_Desc': 'CHEESE,MOZZARELLA,WHL MILK,LO MOIST', 'Water_(g)': 48.38, 'Energ_Kcal': 318, 'Protein_(g)': 21.6, 'Carbohydrt_(g)': 2.47}
# {'_id': ObjectId('667fe0f54d235c4a24913333'), 'NDB_No': 1028, 'Shrt_Desc': 'CHEESE,MOZZARELLA,PART SKIM MILK', 'Water_(g)': 53.78, 'Energ_Kcal': 254, 'Protein_(g)': 24.26, 'Carbohydrt_(g)': 2.77}
# {'_id': ObjectId('667fe0f54d235c4a24913334'), 'NDB_No': 1029, 'Shrt_Desc': 'CHEESE,MOZZARELLA,LO MOIST,PART-SKIM', 'Water_(g)': 47.07, 'Energ_Kcal': 295, 'Protein_(g)': 23.75, 'Carbohydrt_(g)': 5.58}
# {'_id': ObjectId('667fe0f54d235c4a24913335'), 'NDB_No': 1030, 'Shrt_Desc': 'CHEESE,MUENSTER', 'Water_(g)': 41.77, 'Energ_Kcal': 368, 'Protein_(g)': 23.41, 'Carbohydrt_(g)': 1.12}
# {'_id': ObjectId('667fe0f54d235c4a24913336'), 'NDB_No': 1031, 'Shrt_Desc': 'CHEESE,NEUFCHATEL', 'Water_(g)': 63.11, 'Energ_Kcal': 253, 'Protein_(g)': 9.15, 'Carbohydrt_(g)': 3.59}
# {'_id': ObjectId('667fe0f54d235c4a24913337'), 'NDB_No': 1032, 'Shrt_Desc': 'CHEESE,PARMESAN,GRATED', 'Water_(g)': 22.65, 'Energ_Kcal': 420, 'Protein_(g)': 28.42, 'Carbohydrt_(g)': 13.91}
# {'_id': ObjectId('667fe0f54d235c4a24913338'), 'NDB_No': 1033, 'Shrt_Desc': 'CHEESE,PARMESAN,HARD', 'Water_(g)': 29.16, 'Energ_Kcal': 392, 'Protein_(g)': 35.75, 'Carbohydrt_(g)': 3.22}
# {'_id': ObjectId('667fe0f54d235c4a24913339'), 'NDB_No': 1034, 'Shrt_Desc': 'CHEESE,PORT DE SALUT', 'Water_(g)': 45.45, 'Energ_Kcal': 352, 'Protein_(g)': 23.78, 'Carbohydrt_(g)': 0.57}
# {'_id': ObjectId('667fe0f54d235c4a2491333a'), 'NDB_No': 1035, 'Shrt_Desc': 'CHEESE,PROVOLONE', 'Water_(g)': 40.95, 'Energ_Kcal': 351, 'Protein_(g)': 25.58, 'Carbohydrt_(g)': 2.14}
# {'_id': ObjectId('667fe0f54d235c4a2491333b'), 'NDB_No': 1036, 'Shrt_Desc': 'CHEESE,RICOTTA,WHOLE MILK', 'Water_(g)': 71.7, 'Energ_Kcal': 174, 'Protein_(g)': 11.26, 'Carbohydrt_(g)': 3.04}
# {'_id': ObjectId('667fe0f54d235c4a2491333c'), 'NDB_No': 1037, 'Shrt_Desc': 'CHEESE,RICOTTA,PART SKIM MILK', 'Water_(g)': 74.41, 'Energ_Kcal': 138, 'Protein_(g)': 11.39, 'Carbohydrt_(g)': 5.14}
# {'_id': ObjectId('667fe0f54d235c4a2491333d'), 'NDB_No': 1038, 'Shrt_Desc': 'CHEESE,ROMANO', 'Water_(g)': 30.91, 'Energ_Kcal': 387, 'Protein_(g)': 31.8, 'Carbohydrt_(g)': 3.63}
# {'_id': ObjectId('667fe0f54d235c4a2491333e'), 'NDB_No': 1039, 'Shrt_Desc': 'CHEESE,ROQUEFORT', 'Water_(g)': 39.38, 'Energ_Kcal': 369, 'Protein_(g)': 21.54, 'Carbohydrt_(g)': 2.0}
# {'_id': ObjectId('667fe0f54d235c4a2491333f'), 'NDB_No': 1040, 'Shrt_Desc': 'CHEESE,SWISS', 'Water_(g)': 37.63, 'Energ_Kcal': 393, 'Protein_(g)': 26.96, 'Carbohydrt_(g)': 1.44}
# {'_id': ObjectId('667fe0f54d235c4a24913340'), 'NDB_No': 1041, 'Shrt_Desc': 'CHEESE,TILSIT', 'Water_(g)': 42.86, 'Energ_Kcal': 340, 'Protein_(g)': 24.41, 'Carbohydrt_(g)': 1.88}
# {'_id': ObjectId('667fe0f54d235c4a24913341'), 'NDB_No': 1042, 'Shrt_Desc': 'CHEESE,PAST PROCESS,AMERICAN,FORT W/ VITAMIN D', 'Water_(g)': 39.61, 'Energ_Kcal': 366, 'Protein_(g)': 18.13, 'Carbohydrt_(g)': 4.78}
# {'_id': ObjectId('667fe0f54d235c4a24913342'), 'NDB_No': 1043, 'Shrt_Desc': 'CHEESE,PAST PROCESS,PIMENTO', 'Water_(g)': 39.08, 'Energ_Kcal': 375, 'Protein_(g)': 22.13, 'Carbohydrt_(g)': 1.73}
# {'_id': ObjectId('667fe0f54d235c4a24913343'), 'NDB_No': 1044, 'Shrt_Desc': 'CHEESE,PAST PROCESS,SWISS', 'Water_(g)': 42.31, 'Energ_Kcal': 334, 'Protein_(g)': 24.73, 'Carbohydrt_(g)': 2.1}
# {'_id': ObjectId('667fe0f54d235c4a24913344'), 'NDB_No': 1045, 'Shrt_Desc': 'CHEESE FD,COLD PK,AMERICAN', 'Water_(g)': 43.12, 'Energ_Kcal': 331, 'Protein_(g)': 19.66, 'Carbohydrt_(g)': 8.32}
# {'_id': ObjectId('667fe0f54d235c4a24913345'), 'NDB_No': 1046, 'Shrt_Desc': 'CHEESE FD,PAST PROCESS,AMERICAN,VITAMIN D FORT', 'Water_(g)': 44.0, 'Energ_Kcal': 330, 'Protein_(g)': 16.86, 'Carbohydrt_(g)': 8.56}
# {'_id': ObjectId('667fe0f54d235c4a24913346'), 'NDB_No': 1047, 'Shrt_Desc': 'CHEESE FD,PAST PROCESS,SWISS', 'Water_(g)': 43.67, 'Energ_Kcal': 323, 'Protein_(g)': 21.92, 'Carbohydrt_(g)': 4.5}
# {'_id': ObjectId('667fe0f54d235c4a24913347'), 'NDB_No': 1048, 'Shrt_Desc': 'CHEESE SPRD,PAST PROCESS,AMERICAN', 'Water_(g)': 47.65, 'Energ_Kcal': 290, 'Protein_(g)': 16.41, 'Carbohydrt_(g)': 8.73}
# {'_id': ObjectId('667fe0f54d235c4a24913348'), 'NDB_No': 1049, 'Shrt_Desc': 'CREAM,FLUID,HALF AND HALF', 'Water_(g)': 81.24, 'Energ_Kcal': 123, 'Protein_(g)': 3.13, 'Carbohydrt_(g)': 4.73}
# {'_id': ObjectId('667fe0f54d235c4a24913349'), 'NDB_No': 1050, 'Shrt_Desc': 'CREAM,FLUID,LT (COFFEE CRM OR TABLE CRM)', 'Water_(g)': 74.51, 'Energ_Kcal': 191, 'Protein_(g)': 2.96, 'Carbohydrt_(g)': 2.82}
# {'_id': ObjectId('667fe0f54d235c4a2491334a'), 'NDB_No': 1052, 'Shrt_Desc': 'CREAM,FLUID,LT WHIPPING', 'Water_(g)': 63.5, 'Energ_Kcal': 292, 'Protein_(g)': 2.17, 'Carbohydrt_(g)': 2.96}
# {'_id': ObjectId('667fe0f54d235c4a2491334b'), 'NDB_No': 1053, 'Shrt_Desc': 'CREAM,FLUID,HVY WHIPPING', 'Water_(g)': 57.81, 'Energ_Kcal': 340, 'Protein_(g)': 2.84, 'Carbohydrt_(g)': 2.74}
# {'_id': ObjectId('667fe0f54d235c4a2491334c'), 'NDB_No': 1054, 'Shrt_Desc': 'CREAM,WHIPPED,CRM TOPPING,PRESSURIZED', 'Water_(g)': 61.33, 'Energ_Kcal': 257, 'Protein_(g)': 3.2, 'Carbohydrt_(g)': 12.49}
# {'_id': ObjectId('667fe0f54d235c4a2491334d'), 'NDB_No': 1055, 'Shrt_Desc': 'CREAM,SOUR,RED FAT,CULTURED', 'Water_(g)': 80.14, 'Energ_Kcal': 135, 'Protein_(g)': 2.94, 'Carbohydrt_(g)': 4.26}
# {'_id': ObjectId('667fe0f54d235c4a2491334e'), 'NDB_No': 1056, 'Shrt_Desc': 'CREAM,SOUR,CULTURED', 'Water_(g)': 73.07, 'Energ_Kcal': 198, 'Protein_(g)': 2.44, 'Carbohydrt_(g)': 4.63}
# {'_id': ObjectId('667fe0f54d235c4a2491334f'), 'NDB_No': 1057, 'Shrt_Desc': 'EGGNOG', 'Water_(g)': 82.54, 'Energ_Kcal': 88, 'Protein_(g)': 4.55, 'Carbohydrt_(g)': 8.05}
# {'_id': ObjectId('667fe0f54d235c4a24913350'), 'NDB_No': 1058, 'Shrt_Desc': 'SOUR DRSNG,NON-BUTTERFAT,CULTURED,FILLED CREAM-TYPE', 'Water_(g)': 74.79, 'Energ_Kcal': 178, 'Protein_(g)': 3.25, 'Carbohydrt_(g)': 4.68}
# {'_id': ObjectId('667fe0f54d235c4a24913351'), 'NDB_No': 1059, 'Shrt_Desc': 'MILK,FILLED,FLUID,W/BLEND OF HYDR VEG OILS', 'Water_(g)': 87.67, 'Energ_Kcal': 63, 'Protein_(g)': 3.33, 'Carbohydrt_(g)': 4.74}
# {'_id': ObjectId('667fe0f54d235c4a24913352'), 'NDB_No': 1060, 'Shrt_Desc': 'MILK,FILLED,FLUID,W/LAURIC ACID OIL', 'Water_(g)': 87.73, 'Energ_Kcal': 63, 'Protein_(g)': 3.33, 'Carbohydrt_(g)': 4.74}
# {'_id': ObjectId('667fe0f54d235c4a24913353'), 'NDB_No': 1061, 'Shrt_Desc': 'CHEESE,AMERICAN,NONFAT OR FAT FREE', 'Water_(g)': 65.47, 'Energ_Kcal': 126, 'Protein_(g)': 21.05, 'Carbohydrt_(g)': 10.53}
# {'_id': ObjectId('667fe0f54d235c4a24913354'), 'NDB_No': 1067, 'Shrt_Desc': 'CREAM SUB,LIQ,W/HYDR VEG OIL&SOY PROT', 'Water_(g)': 77.27, 'Energ_Kcal': 136, 'Protein_(g)': 1.0, 'Carbohydrt_(g)': 11.38}
# {'_id': ObjectId('667fe0f54d235c4a24913355'), 'NDB_No': 1068, 'Shrt_Desc': 'CREAM SUB,LIQ,W/LAURIC ACID OIL&NA CASEINATE', 'Water_(g)': 77.27, 'Energ_Kcal': 136, 'Protein_(g)': 1.0, 'Carbohydrt_(g)': 11.38}
# {'_id': ObjectId('667fe0f54d235c4a24913356'), 'NDB_No': 1069, 'Shrt_Desc': 'CREAM SUBSTITUTE,POWDERED', 'Water_(g)': 2.98, 'Energ_Kcal': 529, 'Protein_(g)': 2.48, 'Carbohydrt_(g)': 59.29}
# {'_id': ObjectId('667fe0f54d235c4a24913357'), 'NDB_No': 1070, 'Shrt_Desc': 'DESSERT TOPPING,POWDERED', 'Water_(g)': 1.47, 'Energ_Kcal': 577, 'Protein_(g)': 4.9, 'Carbohydrt_(g)': 52.54}
# {'_id': ObjectId('667fe0f54d235c4a24913358'), 'NDB_No': 1071, 'Shrt_Desc': 'DESSERT TOPPING,PDR,1.5 OZ PREP W/1/2 CUP MILK', 'Water_(g)': 65.74, 'Energ_Kcal': 194, 'Protein_(g)': 3.61, 'Carbohydrt_(g)': 17.13}
# {'_id': ObjectId('667fe0f54d235c4a24913359'), 'NDB_No': 1072, 'Shrt_Desc': 'DESSERT TOPPING,PRESSURIZED', 'Water_(g)': 60.37, 'Energ_Kcal': 264, 'Protein_(g)': 0.98, 'Carbohydrt_(g)': 16.07}
# {'_id': ObjectId('667fe0f54d235c4a2491335a'), 'NDB_No': 1073, 'Shrt_Desc': 'DESSERT TOPPING,SEMI SOLID,FRZ', 'Water_(g)': 50.21, 'Energ_Kcal': 318, 'Protein_(g)': 1.25, 'Carbohydrt_(g)': 23.05}
# {'_id': ObjectId('667fe0f54d235c4a2491335b'), 'NDB_No': 1074, 'Shrt_Desc': 'SOUR CRM,IMITN,CULTURED', 'Water_(g)': 71.15, 'Energ_Kcal': 208, 'Protein_(g)': 2.4, 'Carbohydrt_(g)': 6.63}
# {'_id': ObjectId('667fe0f54d235c4a2491335c'), 'NDB_No': 1076, 'Shrt_Desc': 'MILK SUBSTITUTES,FLUID,W/LAURIC ACID OIL', 'Water_(g)': 88.18, 'Energ_Kcal': 61, 'Protein_(g)': 1.75, 'Carbohydrt_(g)': 6.16}
# {'_id': ObjectId('667fe0f54d235c4a2491335d'), 'NDB_No': 1077, 'Shrt_Desc': 'MILK,WHL,3.25% MILKFAT,W/ ADDED VITAMIN D', 'Water_(g)': 88.13, 'Energ_Kcal': 61, 'Protein_(g)': 3.15, 'Carbohydrt_(g)': 4.8}
# {'_id': ObjectId('667fe0f54d235c4a2491335e'), 'NDB_No': 1078, 'Shrt_Desc': 'MILK,PRODUCER,FLUID,3.7% MILKFAT', 'Water_(g)': 87.69, 'Energ_Kcal': 64, 'Protein_(g)': 3.28, 'Carbohydrt_(g)': 4.65}
# {'_id': ObjectId('667fe0f54d235c4a2491335f'), 'NDB_No': 1079, 'Shrt_Desc': 'MILK,RED FAT,FLUID,2% MILKFAT,W/ ADDED VIT A & VITAMIN D', 'Water_(g)': 89.21, 'Energ_Kcal': 50, 'Protein_(g)': 3.3, 'Carbohydrt_(g)': 4.8}
# {'_id': ObjectId('667fe0f54d235c4a24913360'), 'NDB_No': 1080, 'Shrt_Desc': 'MILK,RED FAT,FLUID,2% MILKFAT,W/ ADDED NFMS, VIT A & VIT D', 'Water_(g)': 88.86, 'Energ_Kcal': 51, 'Protein_(g)': 3.48, 'Carbohydrt_(g)': 4.97}
# {'_id': ObjectId('667fe0f54d235c4a24913361'), 'NDB_No': 1081, 'Shrt_Desc': 'MILK,RED FAT,FLUID,2% MILKFAT,PROT FORT,W/ ADDED VIT A & D', 'Water_(g)': 87.71, 'Energ_Kcal': 56, 'Protein_(g)': 3.95, 'Carbohydrt_(g)': 5.49}
# {'_id': ObjectId('667fe0f54d235c4a24913362'), 'NDB_No': 1082, 'Shrt_Desc': 'MILK,LOWFAT,FLUID,1% MILKFAT,W/ ADDED VIT A & VITAMIN D', 'Water_(g)': 89.92, 'Energ_Kcal': 42, 'Protein_(g)': 3.37, 'Carbohydrt_(g)': 4.99}
# {'_id': ObjectId('667fe0f54d235c4a24913363'), 'NDB_No': 1083, 'Shrt_Desc': 'MILK,LOWFAT,FLUID,1% MILKFAT,W/ ADD NONFAT MILK SOL,VIT A/ D', 'Water_(g)': 89.81, 'Energ_Kcal': 43, 'Protein_(g)': 3.48, 'Carbohydrt_(g)': 4.97}
# {'_id': ObjectId('667fe0f54d235c4a24913364'), 'NDB_No': 1084, 'Shrt_Desc': 'MILK,LOWFAT,FLUID,1% MILKFAT,PROT FORT,W/ ADDED VIT A & D', 'Water_(g)': 88.74, 'Energ_Kcal': 48, 'Protein_(g)': 3.93, 'Carbohydrt_(g)': 5.52}
# {'_id': ObjectId('667fe0f54d235c4a24913365'), 'NDB_No': 1085, 'Shrt_Desc': 'MILK,NONFAT,FLUID,W/ ADDED VIT A & VIT D (FAT FREE OR SKIM)', 'Water_(g)': 90.84, 'Energ_Kcal': 34, 'Protein_(g)': 3.37, 'Carbohydrt_(g)': 4.96}
# {'_id': ObjectId('667fe0f54d235c4a24913366'), 'NDB_No': 1086, 'Shrt_Desc': 'MILK,NONFAT,FLUID,W/ ADDED NONFAT MILK SOL,VIT A & VIT D', 'Water_(g)': 90.38, 'Energ_Kcal': 37, 'Protein_(g)': 3.57, 'Carbohydrt_(g)': 5.02}
# {'_id': ObjectId('667fe0f54d235c4a24913367'), 'NDB_No': 1087, 'Shrt_Desc': 'MILK,NONFAT,FLUID,PROT FORT,W/ ADD VIT A & D (FAT FREE/SKIM)', 'Water_(g)': 89.36, 'Energ_Kcal': 41, 'Protein_(g)': 3.96, 'Carbohydrt_(g)': 5.56}
# {'_id': ObjectId('667fe0f54d235c4a24913368'), 'NDB_No': 1088, 'Shrt_Desc': 'MILK,BTTRMLK,FLUID,CULTURED,LOWFAT', 'Water_(g)': 90.13, 'Energ_Kcal': 40, 'Protein_(g)': 3.31, 'Carbohydrt_(g)': 4.79}
# {'_id': ObjectId('667fe0f54d235c4a24913369'), 'NDB_No': 1089, 'Shrt_Desc': 'MILK,LO NA,FLUID', 'Water_(g)': 88.2, 'Energ_Kcal': 61, 'Protein_(g)': 3.1, 'Carbohydrt_(g)': 4.46}
# {'_id': ObjectId('667fe0f54d235c4a2491336a'), 'NDB_No': 1090, 'Shrt_Desc': 'MILK,DRY,WHL,W/ ADDED VITAMIN D', 'Water_(g)': 2.47, 'Energ_Kcal': 496, 'Protein_(g)': 26.32, 'Carbohydrt_(g)': 38.42}
# {'_id': ObjectId('667fe0f54d235c4a2491336b'), 'NDB_No': 1091, 'Shrt_Desc': 'MILK,DRY,NONFAT,REG,WO/ ADDED VIT A & VITAMIN D', 'Water_(g)': 3.16, 'Energ_Kcal': 362, 'Protein_(g)': 36.16, 'Carbohydrt_(g)': 51.98}
# {'_id': ObjectId('667fe0f54d235c4a2491336c'), 'NDB_No': 1092, 'Shrt_Desc': 'MILK,DRY,NONFAT,INST,W/ ADDED VIT A & VITAMIN D', 'Water_(g)': 3.96, 'Energ_Kcal': 358, 'Protein_(g)': 35.1, 'Carbohydrt_(g)': 52.19}
# {'_id': ObjectId('667fe0f54d235c4a2491336d'), 'NDB_No': 1093, 'Shrt_Desc': 'MILK,DRY,NONFAT,CA RED', 'Water_(g)': 4.9, 'Energ_Kcal': 354, 'Protein_(g)': 35.5, 'Carbohydrt_(g)': 51.8}
# {'_id': ObjectId('667fe0f54d235c4a2491336e'), 'NDB_No': 1094, 'Shrt_Desc': 'MILK,BUTTERMILK,DRIED', 'Water_(g)': 2.97, 'Energ_Kcal': 387, 'Protein_(g)': 34.3, 'Carbohydrt_(g)': 49.0}
# {'_id': ObjectId('667fe0f54d235c4a2491336f'), 'NDB_No': 1095, 'Shrt_Desc': 'MILK,CND,COND,SWTND', 'Water_(g)': 27.16, 'Energ_Kcal': 321, 'Protein_(g)': 7.91, 'Carbohydrt_(g)': 54.4}
# {'_id': ObjectId('667fe0f54d235c4a24913370'), 'NDB_No': 1096, 'Shrt_Desc': 'MILK,CND,EVAP,W/ ADDED VITAMIN D & WO/ ADDED VIT A', 'Water_(g)': 74.04, 'Energ_Kcal': 134, 'Protein_(g)': 6.81, 'Carbohydrt_(g)': 10.04}
# {'_id': ObjectId('667fe0f54d235c4a24913371'), 'NDB_No': 1097, 'Shrt_Desc': 'MILK,CND,EVAP,NONFAT,W/ ADDED VIT A & VITAMIN D', 'Water_(g)': 79.4, 'Energ_Kcal': 78, 'Protein_(g)': 7.55, 'Carbohydrt_(g)': 11.35}
# {'_id': ObjectId('667fe0f54d235c4a24913372'), 'NDB_No': 1102, 'Shrt_Desc': 'MILK,CHOC,FLUID,COMM,WHL,W/ ADDED VIT A & VITAMIN D', 'Water_(g)': 82.3, 'Energ_Kcal': 83, 'Protein_(g)': 3.17, 'Carbohydrt_(g)': 10.34}
# {'_id': ObjectId('667fe0f54d235c4a24913373'), 'NDB_No': 1103, 'Shrt_Desc': 'MILK,CHOC,FLUID,COMM,RED FAT', 'Water_(g)': 82.17, 'Energ_Kcal': 76, 'Protein_(g)': 2.99, 'Carbohydrt_(g)': 12.13}
# {'_id': ObjectId('667fe0f54d235c4a24913374'), 'NDB_No': 1104, 'Shrt_Desc': 'MILK,CHOC,LOWFAT,W/ ADDED VIT A & VITAMIN D', 'Water_(g)': 84.91, 'Energ_Kcal': 62, 'Protein_(g)': 3.46, 'Carbohydrt_(g)': 9.86}
# {'_id': ObjectId('667fe0f54d235c4a24913375'), 'NDB_No': 1105, 'Shrt_Desc': 'MILK,CHOC BEV,HOT COCOA,HOMEMADE', 'Water_(g)': 82.45, 'Energ_Kcal': 77, 'Protein_(g)': 3.52, 'Carbohydrt_(g)': 10.74}
# {'_id': ObjectId('667fe0f54d235c4a24913376'), 'NDB_No': 1106, 'Shrt_Desc': 'MILK,GOAT,FLUID,W/ ADDED VITAMIN D', 'Water_(g)': 87.03, 'Energ_Kcal': 69, 'Protein_(g)': 3.56, 'Carbohydrt_(g)': 4.45}
# {'_id': ObjectId('667fe0f54d235c4a24913377'), 'NDB_No': 1107, 'Shrt_Desc': 'MILK,HUMAN,MATURE,FLUID', 'Water_(g)': 87.5, 'Energ_Kcal': 70, 'Protein_(g)': 1.03, 'Carbohydrt_(g)': 6.89}
# {'_id': ObjectId('667fe0f54d235c4a24913378'), 'NDB_No': 1108, 'Shrt_Desc': 'MILK,INDIAN BUFFALO,FLUID', 'Water_(g)': 83.39, 'Energ_Kcal': 97, 'Protein_(g)': 3.75, 'Carbohydrt_(g)': 5.18}
# {'_id': ObjectId('667fe0f54d235c4a24913379'), 'NDB_No': 1109, 'Shrt_Desc': 'MILK,SHEEP,FLUID', 'Water_(g)': 80.7, 'Energ_Kcal': 108, 'Protein_(g)': 5.98, 'Carbohydrt_(g)': 5.36}
# {'_id': ObjectId('667fe0f54d235c4a2491337a'), 'NDB_No': 1110, 'Shrt_Desc': 'MILK SHAKES,THICK CHOC', 'Water_(g)': 72.2, 'Energ_Kcal': 119, 'Protein_(g)': 3.05, 'Carbohydrt_(g)': 21.15}
# {'_id': ObjectId('667fe0f54d235c4a2491337b'), 'NDB_No': 1111, 'Shrt_Desc': 'MILK SHAKES,THICK VANILLA', 'Water_(g)': 74.45, 'Energ_Kcal': 112, 'Protein_(g)': 3.86, 'Carbohydrt_(g)': 17.75}
# {'_id': ObjectId('667fe0f54d235c4a2491337c'), 'NDB_No': 1112, 'Shrt_Desc': 'WHEY,ACID,FLUID', 'Water_(g)': 93.42, 'Energ_Kcal': 24, 'Protein_(g)': 0.76, 'Carbohydrt_(g)': 5.12}
# {'_id': ObjectId('667fe0f54d235c4a2491337d'), 'NDB_No': 1113, 'Shrt_Desc': 'WHEY,ACID,DRIED', 'Water_(g)': 3.51, 'Energ_Kcal': 339, 'Protein_(g)': 11.73, 'Carbohydrt_(g)': 73.45}
# {'_id': ObjectId('667fe0f54d235c4a2491337e'), 'NDB_No': 1114, 'Shrt_Desc': 'WHEY,SWEET,FLUID', 'Water_(g)': 93.12, 'Energ_Kcal': 27, 'Protein_(g)': 0.85, 'Carbohydrt_(g)': 5.14}
# {'_id': ObjectId('667fe0f54d235c4a2491337f'), 'NDB_No': 1115, 'Shrt_Desc': 'WHEY,SWEET,DRIED', 'Water_(g)': 3.19, 'Energ_Kcal': 353, 'Protein_(g)': 12.93, 'Carbohydrt_(g)': 74.46}
# {'_id': ObjectId('667fe0f54d235c4a24913380'), 'NDB_No': 1116, 'Shrt_Desc': 'YOGURT,PLN,WHL MILK,8 GRAMS PROT PER 8 OZ', 'Water_(g)': 87.9, 'Energ_Kcal': 61, 'Protein_(g)': 3.47, 'Carbohydrt_(g)': 4.66}
# {'_id': ObjectId('667fe0f54d235c4a24913381'), 'NDB_No': 1117, 'Shrt_Desc': 'YOGURT,PLN,LOFAT,12 GRAMS PROT PER 8 OZ', 'Water_(g)': 85.07, 'Energ_Kcal': 63, 'Protein_(g)': 5.25, 'Carbohydrt_(g)': 7.04}
# {'_id': ObjectId('667fe0f54d235c4a24913382'), 'NDB_No': 1118, 'Shrt_Desc': 'YOGURT,PLN,SKIM MILK,13 GRAMS PROT PER 8 OZ', 'Water_(g)': 85.23, 'Energ_Kcal': 56, 'Protein_(g)': 5.73, 'Carbohydrt_(g)': 7.68}
# {'_id': ObjectId('667fe0f54d235c4a24913383'), 'NDB_No': 1119, 'Shrt_Desc': 'YOGURT,VANILLA,LOFAT,11 GRAMS PROT PER 8 OZ', 'Water_(g)': 79.0, 'Energ_Kcal': 85, 'Protein_(g)': 4.93, 'Carbohydrt_(g)': 13.8}
# {'_id': ObjectId('667fe0f54d235c4a24913384'), 'NDB_No': 1120, 'Shrt_Desc': 'YOGURT,FRUIT,LOFAT,9 GRAMS PROT PER 8 OZ', 'Water_(g)': 75.3, 'Energ_Kcal': 99, 'Protein_(g)': 3.98, 'Carbohydrt_(g)': 18.64}
# {'_id': ObjectId('667fe0f54d235c4a24913385'), 'NDB_No': 1121, 'Shrt_Desc': 'YOGURT,FRUIT,LOFAT,10 GRAMS PROT PER 8 OZ', 'Water_(g)': 74.48, 'Energ_Kcal': 102, 'Protein_(g)': 4.37, 'Carbohydrt_(g)': 19.05}
# {'_id': ObjectId('667fe0f54d235c4a24913386'), 'NDB_No': 1122, 'Shrt_Desc': 'YOGURT,FRUIT,LOFAT,11 GRAMS PROT PER 8 OZ', 'Water_(g)': 74.1, 'Energ_Kcal': 105, 'Protein_(g)': 4.86, 'Carbohydrt_(g)': 18.6}
# {'_id': ObjectId('667fe0f54d235c4a24913387'), 'NDB_No': 1123, 'Shrt_Desc': 'EGG,WHL,RAW,FRSH', 'Water_(g)': 76.15, 'Energ_Kcal': 143, 'Protein_(g)': 12.56, 'Carbohydrt_(g)': 0.72}
# {'_id': ObjectId('667fe0f54d235c4a24913388'), 'NDB_No': 1124, 'Shrt_Desc': 'EGG,WHITE,RAW,FRESH', 'Water_(g)': 87.57, 'Energ_Kcal': 52, 'Protein_(g)': 10.9, 'Carbohydrt_(g)': 0.73}
# {'_id': ObjectId('667fe0f54d235c4a24913389'), 'NDB_No': 1125, 'Shrt_Desc': 'EGG,YOLK,RAW,FRSH', 'Water_(g)': 52.31, 'Energ_Kcal': 322, 'Protein_(g)': 15.86, 'Carbohydrt_(g)': 3.59}
# {'_id': ObjectId('667fe0f54d235c4a2491338a'), 'NDB_No': 1126, 'Shrt_Desc': 'EGG,YOLK,RAW,FRZ,PAST', 'Water_(g)': 56.44, 'Energ_Kcal': 296, 'Protein_(g)': 15.53, 'Carbohydrt_(g)': 0.81}
# {'_id': ObjectId('667fe0f54d235c4a2491338b'), 'NDB_No': 1127, 'Shrt_Desc': 'EGG,YOLK,RAW,FRZ,SUGARED,PAST', 'Water_(g)': 51.23, 'Energ_Kcal': 307, 'Protein_(g)': 13.87, 'Carbohydrt_(g)': 10.95}
# {'_id': ObjectId('667fe0f54d235c4a2491338c'), 'NDB_No': 1128, 'Shrt_Desc': 'EGG,WHL,CKD,FRIED', 'Water_(g)': 69.47, 'Energ_Kcal': 196, 'Protein_(g)': 13.61, 'Carbohydrt_(g)': 0.83}
# {'_id': ObjectId('667fe0f54d235c4a2491338d'), 'NDB_No': 1129, 'Shrt_Desc': 'EGG,WHL,CKD,HARD-BOILED', 'Water_(g)': 74.62, 'Energ_Kcal': 155, 'Protein_(g)': 12.58, 'Carbohydrt_(g)': 1.12}
# {'_id': ObjectId('667fe0f54d235c4a2491338e'), 'NDB_No': 1130, 'Shrt_Desc': 'EGG,WHOLE,COOKED,OMELET', 'Water_(g)': 76.13, 'Energ_Kcal': 154, 'Protein_(g)': 10.57, 'Carbohydrt_(g)': 0.64}
# {'_id': ObjectId('667fe0f54d235c4a2491338f'), 'NDB_No': 1131, 'Shrt_Desc': 'EGG,WHL,CKD,POACHED', 'Water_(g)': 75.85, 'Energ_Kcal': 143, 'Protein_(g)': 12.51, 'Carbohydrt_(g)': 0.71}
# {'_id': ObjectId('667fe0f54d235c4a24913390'), 'NDB_No': 1132, 'Shrt_Desc': 'EGG,WHL,CKD,SCRMBLD', 'Water_(g)': 76.4, 'Energ_Kcal': 149, 'Protein_(g)': 9.99, 'Carbohydrt_(g)': 1.61}
# {'_id': ObjectId('667fe0f54d235c4a24913391'), 'NDB_No': 1133, 'Shrt_Desc': 'EGG,WHL,DRIED', 'Water_(g)': 2.78, 'Energ_Kcal': 592, 'Protein_(g)': 48.05, 'Carbohydrt_(g)': 1.13}
# {'_id': ObjectId('667fe0f54d235c4a24913392'), 'NDB_No': 1134, 'Shrt_Desc': 'EGG,WHL,DRIED,STABILIZED,GLUCOSE RED', 'Water_(g)': 1.87, 'Energ_Kcal': 615, 'Protein_(g)': 48.17, 'Carbohydrt_(g)': 2.38}
# {'_id': ObjectId('667fe0f54d235c4a24913393'), 'NDB_No': 1135, 'Shrt_Desc': 'EGG,WHITE,DRIED,FLAKES,STABILIZED,GLUCOSE RED', 'Water_(g)': 14.62, 'Energ_Kcal': 351, 'Protein_(g)': 76.92, 'Carbohydrt_(g)': 4.17}
# {'_id': ObjectId('667fe0f54d235c4a24913394'), 'NDB_No': 1136, 'Shrt_Desc': 'EGG,WHITE,DRIED,PDR,STABILIZED,GLUCOSE RED', 'Water_(g)': 8.54, 'Energ_Kcal': 376, 'Protein_(g)': 82.4, 'Carbohydrt_(g)': 4.47}
# {'_id': ObjectId('667fe0f54d235c4a24913395'), 'NDB_No': 1137, 'Shrt_Desc': 'EGG,YOLK,DRIED', 'Water_(g)': 3.08, 'Energ_Kcal': 669, 'Protein_(g)': 33.63, 'Carbohydrt_(g)': 0.66}
# {'_id': ObjectId('667fe0f54d235c4a24913396'), 'NDB_No': 1138, 'Shrt_Desc': 'EGG,DUCK,WHOLE,FRESH,RAW', 'Water_(g)': 70.83, 'Energ_Kcal': 185, 'Protein_(g)': 12.81, 'Carbohydrt_(g)': 1.45}
# {'_id': ObjectId('667fe0f54d235c4a24913397'), 'NDB_No': 1139, 'Shrt_Desc': 'EGG,GOOSE,WHOLE,FRESH,RAW', 'Water_(g)': 70.43, 'Energ_Kcal': 185, 'Protein_(g)': 13.87, 'Carbohydrt_(g)': 1.35}
# {'_id': ObjectId('667fe0f54d235c4a24913398'), 'NDB_No': 1140, 'Shrt_Desc': 'EGG,QUAIL,WHOLE,FRESH,RAW', 'Water_(g)': 74.35, 'Energ_Kcal': 158, 'Protein_(g)': 13.05, 'Carbohydrt_(g)': 0.41}
# {'_id': ObjectId('667fe0f54d235c4a24913399'), 'NDB_No': 1141, 'Shrt_Desc': 'EGG,TURKEY,WHL,FRSH,RAW', 'Water_(g)': 72.5, 'Energ_Kcal': 171, 'Protein_(g)': 13.68, 'Carbohydrt_(g)': 1.15}
# {'_id': ObjectId('667fe0f54d235c4a2491339a'), 'NDB_No': 1144, 'Shrt_Desc': 'EGG SUBSTITUTE,POWDER', 'Water_(g)': 3.86, 'Energ_Kcal': 444, 'Protein_(g)': 55.5, 'Carbohydrt_(g)': 21.8}
# {'_id': ObjectId('667fe0f54d235c4a2491339b'), 'NDB_No': 1145, 'Shrt_Desc': 'BUTTER,WITHOUT SALT', 'Water_(g)': 17.94, 'Energ_Kcal': 717, 'Protein_(g)': 0.85, 'Carbohydrt_(g)': 0.06}
# {'_id': ObjectId('667fe0f54d235c4a2491339c'), 'NDB_No': 1146, 'Shrt_Desc': 'CHEESE,PARMESAN,SHREDDED', 'Water_(g)': 25.0, 'Energ_Kcal': 415, 'Protein_(g)': 37.86, 'Carbohydrt_(g)': 3.41}
# {'_id': ObjectId('667fe0f54d235c4a2491339d'), 'NDB_No': 1151, 'Shrt_Desc': 'MILK,NONFAT,FLUID,WO/ ADDED VIT A & VIT D (FAT FREE OR SKIM)', 'Water_(g)': 90.84, 'Energ_Kcal': 34, 'Protein_(g)': 3.37, 'Carbohydrt_(g)': 4.96}
# {'_id': ObjectId('667fe0f54d235c4a2491339e'), 'NDB_No': 1152, 'Shrt_Desc': 'MILK,RED FAT,FLUID,2% MILKFAT,W/ NONFAT MILK SOL,WO/ VIT A', 'Water_(g)': 87.71, 'Energ_Kcal': 56, 'Protein_(g)': 3.95, 'Carbohydrt_(g)': 5.49}
# {'_id': ObjectId('667fe0f54d235c4a2491339f'), 'NDB_No': 1153, 'Shrt_Desc': 'MILK,CND,EVAP,W/ VIT A', 'Water_(g)': 74.04, 'Energ_Kcal': 134, 'Protein_(g)': 6.81, 'Carbohydrt_(g)': 10.04}
# {'_id': ObjectId('667fe0f54d235c4a249133a0'), 'NDB_No': 1154, 'Shrt_Desc': 'MILK,DRY,NONFAT,REG,W/ ADDED VIT A & VITAMIN D', 'Water_(g)': 3.16, 'Energ_Kcal': 362, 'Protein_(g)': 36.16, 'Carbohydrt_(g)': 51.98}
# {'_id': ObjectId('667fe0f54d235c4a249133a1'), 'NDB_No': 1155, 'Shrt_Desc': 'MILK,DRY,NONFAT,INST,WO/ ADDED VIT A & VITAMIN D', 'Water_(g)': 3.96, 'Energ_Kcal': 358, 'Protein_(g)': 35.1, 'Carbohydrt_(g)': 52.19}
# {'_id': ObjectId('667fe0f54d235c4a249133a2'), 'NDB_No': 1156, 'Shrt_Desc': 'CHEESE,GOAT,HARD TYPE', 'Water_(g)': 29.01, 'Energ_Kcal': 452, 'Protein_(g)': 30.52, 'Carbohydrt_(g)': 2.17}
# {'_id': ObjectId('667fe0f54d235c4a249133a3'), 'NDB_No': 1157, 'Shrt_Desc': 'CHEESE,GOAT,SEMISOFT TYPE', 'Water_(g)': 45.52, 'Energ_Kcal': 364, 'Protein_(g)': 21.58, 'Carbohydrt_(g)': 0.12}
# {'_id': ObjectId('667fe0f54d235c4a249133a4'), 'NDB_No': 1159, 'Shrt_Desc': 'CHEESE,GOAT,SOFT TYPE', 'Water_(g)': 60.75, 'Energ_Kcal': 264, 'Protein_(g)': 18.52, 'Carbohydrt_(g)': 0.0}
# {'_id': ObjectId('667fe0f54d235c4a249133a5'), 'NDB_No': 1160, 'Shrt_Desc': 'EGG,YOLK,RAW,FRZ,SALTED,PAST', 'Water_(g)': 50.87, 'Energ_Kcal': 275, 'Protein_(g)': 14.07, 'Carbohydrt_(g)': 1.77}
# {'_id': ObjectId('667fe0f54d235c4a249133a6'), 'NDB_No': 1161, 'Shrt_Desc': 'CHEESE SUB,MOZZARELLA', 'Water_(g)': 47.36, 'Energ_Kcal': 248, 'Protein_(g)': 11.47, 'Carbohydrt_(g)': 23.67}
# {'_id': ObjectId('667fe0f54d235c4a249133a7'), 'NDB_No': 1164, 'Shrt_Desc': 'CHEESE SAU,PREP FROM RECIPE', 'Water_(g)': 66.86, 'Energ_Kcal': 197, 'Protein_(g)': 10.33, 'Carbohydrt_(g)': 5.48}
# {'_id': ObjectId('667fe0f54d235c4a249133a8'), 'NDB_No': 1165, 'Shrt_Desc': 'CHEESE,MEXICAN,QUESO ANEJO', 'Water_(g)': 38.06, 'Energ_Kcal': 373, 'Protein_(g)': 21.44, 'Carbohydrt_(g)': 4.63}
# {'_id': ObjectId('667fe0f54d235c4a249133a9'), 'NDB_No': 1166, 'Shrt_Desc': 'CHEESE,MEXICAN,QUESO ASADERO', 'Water_(g)': 42.16, 'Energ_Kcal': 356, 'Protein_(g)': 22.6, 'Carbohydrt_(g)': 2.87}
# {'_id': ObjectId('667fe0f54d235c4a249133aa'), 'NDB_No': 1167, 'Shrt_Desc': 'CHEESE,MEXICAN,QUESO CHIHUAHUA', 'Water_(g)': 39.13, 'Energ_Kcal': 374, 'Protein_(g)': 21.56, 'Carbohydrt_(g)': 5.56}
# {'_id': ObjectId('667fe0f54d235c4a249133ab'), 'NDB_No': 1168, 'Shrt_Desc': 'CHEESE,LOFAT,CHEDDAR OR COLBY', 'Water_(g)': 63.1, 'Energ_Kcal': 173, 'Protein_(g)': 24.35, 'Carbohydrt_(g)': 1.91}
# {'_id': ObjectId('667fe0f54d235c4a249133ac'), 'NDB_No': 1169, 'Shrt_Desc': 'CHEESE,LOW-SODIUM,CHEDDAR OR COLBY', 'Water_(g)': 38.98, 'Energ_Kcal': 398, 'Protein_(g)': 24.35, 'Carbohydrt_(g)': 1.91}
# {'_id': ObjectId('667fe0f54d235c4a249133ad'), 'NDB_No': 1171, 'Shrt_Desc': 'EGG,WHL,RAW,FRZ,PAST', 'Water_(g)': 75.81, 'Energ_Kcal': 147, 'Protein_(g)': 12.33, 'Carbohydrt_(g)': 1.01}
# {'_id': ObjectId('667fe0f54d235c4a249133ae'), 'NDB_No': 1172, 'Shrt_Desc': 'EGG,WHITE,RAW,FRZ,PAST', 'Water_(g)': 88.17, 'Energ_Kcal': 48, 'Protein_(g)': 10.2, 'Carbohydrt_(g)': 1.04}
# {'_id': ObjectId('667fe0f54d235c4a249133af'), 'NDB_No': 1173, 'Shrt_Desc': 'EGG,WHITE,DRIED', 'Water_(g)': 5.8, 'Energ_Kcal': 382, 'Protein_(g)': 81.1, 'Carbohydrt_(g)': 7.8}
# {'_id': ObjectId('667fe0f54d235c4a249133b0'), 'NDB_No': 1174, 'Shrt_Desc': 'MILK,RED FAT,FLUID,2% MILKFAT,WO/ ADDED VIT A & VIT D', 'Water_(g)': 89.21, 'Energ_Kcal': 50, 'Protein_(g)': 3.3, 'Carbohydrt_(g)': 4.8}
# {'_id': ObjectId('667fe0f54d235c4a249133b1'), 'NDB_No': 1175, 'Shrt_Desc': 'MILK,FLUID,1% FAT,WO/ ADDED VIT A & VIT D', 'Water_(g)': 89.92, 'Energ_Kcal': 42, 'Protein_(g)': 3.37, 'Carbohydrt_(g)': 4.99}
# {'_id': ObjectId('667fe0f54d235c4a249133b2'), 'NDB_No': 1178, 'Shrt_Desc': 'SOUR CREAM,REDUCED FAT', 'Water_(g)': 71.0, 'Energ_Kcal': 181, 'Protein_(g)': 7.0, 'Carbohydrt_(g)': 7.0}
# {'_id': ObjectId('667fe0f54d235c4a249133b3'), 'NDB_No': 1179, 'Shrt_Desc': 'SOUR CREAM,LIGHT', 'Water_(g)': 78.1, 'Energ_Kcal': 136, 'Protein_(g)': 3.5, 'Carbohydrt_(g)': 7.1}
# {'_id': ObjectId('667fe0f54d235c4a249133b4'), 'NDB_No': 1180, 'Shrt_Desc': 'SOUR CREAM,FAT FREE', 'Water_(g)': 80.6, 'Energ_Kcal': 74, 'Protein_(g)': 3.1, 'Carbohydrt_(g)': 15.6}
# {'_id': ObjectId('667fe0f54d235c4a249133b5'), 'NDB_No': 1182, 'Shrt_Desc': 'USDA COMMODITY,CHS,CHEDDAR,RED FAT', 'Water_(g)': 48.2, 'Energ_Kcal': 282, 'Protein_(g)': 27.2, 'Carbohydrt_(g)': 2.0}
# {'_id': ObjectId('667fe0f54d235c4a249133b6'), 'NDB_No': 1184, 'Shrt_Desc': 'YOGURT,VAN OR LEM FLAV,NONFAT MILK,SWTND W/LOW-CALORIE SWTNR', 'Water_(g)': 87.43, 'Energ_Kcal': 43, 'Protein_(g)': 3.86, 'Carbohydrt_(g)': 7.5}
# {'_id': ObjectId('667fe0f54d235c4a249133b7'), 'NDB_No': 1185, 'Shrt_Desc': 'PARMESAN CHS TOPPING,FAT FREE', 'Water_(g)': 8.6, 'Energ_Kcal': 370, 'Protein_(g)': 40.0, 'Carbohydrt_(g)': 40.0}
# {'_id': ObjectId('667fe0f54d235c4a249133b8'), 'NDB_No': 1186, 'Shrt_Desc': 'CHEESE,CREAM,FAT FREE', 'Water_(g)': 71.87, 'Energ_Kcal': 105, 'Protein_(g)': 15.69, 'Carbohydrt_(g)': 7.66}
# {'_id': ObjectId('667fe0f54d235c4a249133b9'), 'NDB_No': 1187, 'Shrt_Desc': 'YOGURT,CHOC,NONFAT MILK', 'Water_(g)': 71.57, 'Energ_Kcal': 112, 'Protein_(g)': 3.53, 'Carbohydrt_(g)': 23.53}
# {'_id': ObjectId('667fe0f54d235c4a249133ba'), 'NDB_No': 1188, 'Shrt_Desc': 'KRAFT CHEEZ WHIZ PAST PROCESS CHS SAU', 'Water_(g)': 51.5, 'Energ_Kcal': 276, 'Protein_(g)': 12.0, 'Carbohydrt_(g)': 9.2}
# {'_id': ObjectId('667fe0f54d235c4a249133bb'), 'NDB_No': 1189, 'Shrt_Desc': 'KRAFT CHEEZ WHIZ LT PAST PROCESS CHS PRODUCT', 'Water_(g)': 51.5, 'Energ_Kcal': 215, 'Protein_(g)': 16.3, 'Carbohydrt_(g)': 16.2}
# {'_id': ObjectId('667fe0f54d235c4a249133bc'), 'NDB_No': 1190, 'Shrt_Desc': 'KRAFT FREE SINGLES AMERICAN NONFAT PAST PROCESS CHS PRODUCT', 'Water_(g)': 58.0, 'Energ_Kcal': 148, 'Protein_(g)': 22.7, 'Carbohydrt_(g)': 11.7}
# {'_id': ObjectId('667fe0f54d235c4a249133bd'), 'NDB_No': 1191, 'Shrt_Desc': 'KRAFT VELVEETA PAST PROCESS CHS SPRD', 'Water_(g)': 45.8, 'Energ_Kcal': 303, 'Protein_(g)': 16.3, 'Carbohydrt_(g)': 9.8}
# {'_id': ObjectId('667fe0f54d235c4a249133be'), 'NDB_No': 1192, 'Shrt_Desc': 'KRAFT VELVEETA LT RED FAT PAST PROCESS CHS PRODUCT', 'Water_(g)': 51.3, 'Energ_Kcal': 222, 'Protein_(g)': 19.6, 'Carbohydrt_(g)': 11.8}
# {'_id': ObjectId('667fe0f54d235c4a249133bf'), 'NDB_No': 1193, 'Shrt_Desc': "KRAFT BREAKSTONE'S RED FAT SOUR CRM", 'Water_(g)': 76.2, 'Energ_Kcal': 152, 'Protein_(g)': 4.5, 'Carbohydrt_(g)': 6.5}
# {'_id': ObjectId('667fe0f54d235c4a249133c0'), 'NDB_No': 1194, 'Shrt_Desc': "KRAFT BREAKSTONE'S FREE FAT FREE SOUR CRM", 'Water_(g)': 77.7, 'Energ_Kcal': 91, 'Protein_(g)': 4.7, 'Carbohydrt_(g)': 15.1}
# {'_id': ObjectId('667fe0f54d235c4a249133c1'), 'NDB_No': 1199, 'Shrt_Desc': 'CREAM,HALF & HALF,FAT FREE', 'Water_(g)': 86.0, 'Energ_Kcal': 59, 'Protein_(g)': 2.6, 'Carbohydrt_(g)': 9.0}
# {'_id': ObjectId('667fe0f54d235c4a249133c2'), 'NDB_No': 1200, 'Shrt_Desc': 'REDDI WIP FAT FREE WHIPPED TOPPING', 'Water_(g)': 66.44, 'Energ_Kcal': 149, 'Protein_(g)': 3.0, 'Carbohydrt_(g)': 25.0}
# {'_id': ObjectId('667fe0f54d235c4a249133c3'), 'NDB_No': 1202, 'Shrt_Desc': 'MILK,CHOC,FLUID,COMM,RED FAT,W/ ADDED CA', 'Water_(g)': 82.17, 'Energ_Kcal': 78, 'Protein_(g)': 2.99, 'Carbohydrt_(g)': 12.13}
# {'_id': ObjectId('667fe0f54d235c4a249133c4'), 'NDB_No': 1203, 'Shrt_Desc': 'YOGURT,FRUIT,LOFAT,W/LO CAL SWEETENER', 'Water_(g)': 74.1, 'Energ_Kcal': 105, 'Protein_(g)': 4.86, 'Carbohydrt_(g)': 18.6}
# {'_id': ObjectId('667fe0f54d235c4a249133c5'), 'NDB_No': 1204, 'Shrt_Desc': 'CHEESE,PARMESAN,DRY GRATED,RED FAT', 'Water_(g)': 50.6, 'Energ_Kcal': 265, 'Protein_(g)': 20.0, 'Carbohydrt_(g)': 1.37}
# {'_id': ObjectId('667fe0f54d235c4a249133c6'), 'NDB_No': 1205, 'Shrt_Desc': 'CREAM SUB,FLAV,LIQ', 'Water_(g)': 50.06, 'Energ_Kcal': 251, 'Protein_(g)': 0.69, 'Carbohydrt_(g)': 35.07}
# {'_id': ObjectId('667fe0f54d235c4a249133c7'), 'NDB_No': 1206, 'Shrt_Desc': 'CREAM SUB,FLAV,PDR', 'Water_(g)': 1.52, 'Energ_Kcal': 482, 'Protein_(g)': 0.68, 'Carbohydrt_(g)': 75.42}
# {'_id': ObjectId('667fe0f54d235c4a249133c8'), 'NDB_No': 1208, 'Shrt_Desc': 'CHEESE,PROVOLONE,RED FAT', 'Water_(g)': 50.6, 'Energ_Kcal': 274, 'Protein_(g)': 24.7, 'Carbohydrt_(g)': 3.5}
# {'_id': ObjectId('667fe0f54d235c4a249133c9'), 'NDB_No': 1209, 'Shrt_Desc': 'CHEESE,MEXICAN,BLEND,RED FAT', 'Water_(g)': 48.2, 'Energ_Kcal': 282, 'Protein_(g)': 24.69, 'Carbohydrt_(g)': 3.41}
# {'_id': ObjectId('667fe0f54d235c4a249133ca'), 'NDB_No': 1210, 'Shrt_Desc': 'EGG MIX,USDA CMDTY', 'Water_(g)': 2.78, 'Energ_Kcal': 555, 'Protein_(g)': 35.6, 'Carbohydrt_(g)': 23.97}
# {'_id': ObjectId('667fe0f54d235c4a249133cb'), 'NDB_No': 1211, 'Shrt_Desc': 'MILK,WHL,3.25% MILKFAT,WO/ ADDED VIT A & VITAMIN D', 'Water_(g)': 88.13, 'Energ_Kcal': 61, 'Protein_(g)': 3.15, 'Carbohydrt_(g)': 4.78}
# {'_id': ObjectId('667fe0f54d235c4a249133cc'), 'NDB_No': 1212, 'Shrt_Desc': 'MILK,DRY,WHL,WO/ ADDED VITAMIN D', 'Water_(g)': 2.47, 'Energ_Kcal': 496, 'Protein_(g)': 26.32, 'Carbohydrt_(g)': 38.42}
# {'_id': ObjectId('667fe0f54d235c4a249133cd'), 'NDB_No': 1214, 'Shrt_Desc': 'MILK,CND,EVAP,WO/ ADDED VIT A & VITAMIN D', 'Water_(g)': 74.04, 'Energ_Kcal': 135, 'Protein_(g)': 6.81, 'Carbohydrt_(g)': 10.04}
# {'_id': ObjectId('667fe0f54d235c4a249133ce'), 'NDB_No': 1215, 'Shrt_Desc': 'CHEESE PRODUCT,PAST PROCESS,AMERICAN,RED FAT,FORT W/ VIT D', 'Water_(g)': 51.8, 'Energ_Kcal': 240, 'Protein_(g)': 17.6, 'Carbohydrt_(g)': 10.6}
# {'_id': ObjectId('667fe0f54d235c4a249133cf'), 'NDB_No': 1216, 'Shrt_Desc': 'YOGURT,FRUIT,LOFAT,9 GRAMS PROT PER 8 OZ,FORT W/ VITAMIN D', 'Water_(g)': 75.3, 'Energ_Kcal': 99, 'Protein_(g)': 3.98, 'Carbohydrt_(g)': 18.64}
# {'_id': ObjectId('667fe0f54d235c4a249133d0'), 'NDB_No': 1217, 'Shrt_Desc': 'YOGURT,FRUIT,LOFAT,10 GRAMS PROT PER 8 OZ,FORT W/ VITAMIN D', 'Water_(g)': 74.48, 'Energ_Kcal': 102, 'Protein_(g)': 4.37, 'Carbohydrt_(g)': 19.05}
# {'_id': ObjectId('667fe0f54d235c4a249133d1'), 'NDB_No': 1218, 'Shrt_Desc': 'YOGURT,FRUIT VAR,NONFAT,FORT W/ VITAMIN D', 'Water_(g)': 75.4, 'Energ_Kcal': 95, 'Protein_(g)': 4.4, 'Carbohydrt_(g)': 19.0}
# {'_id': ObjectId('667fe0f54d235c4a249133d2'), 'NDB_No': 1219, 'Shrt_Desc': 'YOGURT,FRUIT,LOWFAT,W/ LO CAL SWTNR,FORT W/ VITAMIN D', 'Water_(g)': 74.1, 'Energ_Kcal': 105, 'Protein_(g)': 4.86, 'Carbohydrt_(g)': 18.6}
# {'_id': ObjectId('667fe0f54d235c4a249133d3'), 'NDB_No': 1220, 'Shrt_Desc': 'YOGURT,VANILLA,LOFAT,11 GRAMS PROT PER 8 OZ,FORT W/ VIT D', 'Water_(g)': 79.0, 'Energ_Kcal': 85, 'Protein_(g)': 4.93, 'Carbohydrt_(g)': 13.8}
# {'_id': ObjectId('667fe0f54d235c4a249133d4'), 'NDB_No': 1221, 'Shrt_Desc': 'YOGURT,VAN/LEM FLAV,NONFAT MILK,W/ LO-CAL SWTNR,FORT W/VIT D', 'Water_(g)': 87.43, 'Energ_Kcal': 43, 'Protein_(g)': 3.86, 'Carbohydrt_(g)': 7.5}
# {'_id': ObjectId('667fe0f54d235c4a249133d5'), 'NDB_No': 1222, 'Shrt_Desc': 'YOGURT,CHOC,NONFAT MILK,FORT W/ VITAMIN D', 'Water_(g)': 71.57, 'Energ_Kcal': 112, 'Protein_(g)': 3.53, 'Carbohydrt_(g)': 23.53}
# {'_id': ObjectId('667fe0f54d235c4a249133d6'), 'NDB_No': 1223, 'Shrt_Desc': 'PROTEIN SUPP,MILK BSD,MUSCLE MILK,PDR', 'Water_(g)': 15.0, 'Energ_Kcal': 411, 'Protein_(g)': 45.71, 'Carbohydrt_(g)': 18.5}
# {'_id': ObjectId('667fe0f54d235c4a249133d7'), 'NDB_No': 1224, 'Shrt_Desc': 'PROTEIN SUPP,MILK BSD,MUSCLE MILK LT,PDR', 'Water_(g)': 12.0, 'Energ_Kcal': 396, 'Protein_(g)': 50.0, 'Carbohydrt_(g)': 22.0}
# {'_id': ObjectId('667fe0f54d235c4a249133d8'), 'NDB_No': 1225, 'Shrt_Desc': 'DULCE DE LECHE', 'Water_(g)': 28.71, 'Energ_Kcal': 315, 'Protein_(g)': 6.84, 'Carbohydrt_(g)': 55.35}
# {'_id': ObjectId('667fe0f54d235c4a249133d9'), 'NDB_No': 1226, 'Shrt_Desc': 'EGG SUB,LIQ OR FRZ,FAT FREE', 'Water_(g)': 87.0, 'Energ_Kcal': 48, 'Protein_(g)': 10.0, 'Carbohydrt_(g)': 2.0}
# {'_id': ObjectId('667fe0f54d235c4a249133da'), 'NDB_No': 1227, 'Shrt_Desc': 'CHEESE,DRY WHITE,QUESO SECO', 'Water_(g)': 42.17, 'Energ_Kcal': 325, 'Protein_(g)': 24.51, 'Carbohydrt_(g)': 2.04}
# {'_id': ObjectId('667fe0f54d235c4a249133db'), 'NDB_No': 1228, 'Shrt_Desc': 'CHEESE,FRSH,QUESO FRESCO', 'Water_(g)': 51.42, 'Energ_Kcal': 299, 'Protein_(g)': 18.09, 'Carbohydrt_(g)': 2.98}
# {'_id': ObjectId('667fe0f54d235c4a249133dc'), 'NDB_No': 1229, 'Shrt_Desc': 'CHEESE,WHITE,QUESO BLANCO', 'Water_(g)': 48.7, 'Energ_Kcal': 310, 'Protein_(g)': 20.38, 'Carbohydrt_(g)': 2.53}
# {'_id': ObjectId('667fe0f54d235c4a249133dd'), 'NDB_No': 1230, 'Shrt_Desc': 'MILK,BTTRMLK,FLUID,WHL', 'Water_(g)': 87.91, 'Energ_Kcal': 62, 'Protein_(g)': 3.21, 'Carbohydrt_(g)': 4.88}
# {'_id': ObjectId('667fe0f54d235c4a249133de'), 'NDB_No': 1231, 'Shrt_Desc': 'YOGURT,VANILLA FLAVOR,LOWFAT MILK,SWTND W/ LO CAL SWTNR', 'Water_(g)': 79.0, 'Energ_Kcal': 86, 'Protein_(g)': 4.93, 'Carbohydrt_(g)': 13.8}
# {'_id': ObjectId('667fe0f54d235c4a249133df'), 'NDB_No': 1235, 'Shrt_Desc': 'YOGURT,FRZ,FLAVORS NOT CHOC,NONFAT MILK,W/ LOW-CALORIE SWTNR', 'Water_(g)': 73.5, 'Energ_Kcal': 104, 'Protein_(g)': 4.4, 'Carbohydrt_(g)': 19.7}
# {'_id': ObjectId('667fe0f54d235c4a249133e0'), 'NDB_No': 1236, 'Shrt_Desc': 'ICE CRM,SOFT SERVE,CHOC', 'Water_(g)': 59.8, 'Energ_Kcal': 222, 'Protein_(g)': 4.1, 'Carbohydrt_(g)': 22.2}
# {'_id': ObjectId('667fe0f54d235c4a249133e1'), 'NDB_No': 1237, 'Shrt_Desc': 'ICE CRM,BAR OR STK,CHOC COVERED', 'Water_(g)': 46.3, 'Energ_Kcal': 331, 'Protein_(g)': 4.1, 'Carbohydrt_(g)': 24.5}
# {'_id': ObjectId('667fe0f54d235c4a249133e2'), 'NDB_No': 1238, 'Shrt_Desc': 'ICE CRM SNDWCH', 'Water_(g)': 48.9, 'Energ_Kcal': 237, 'Protein_(g)': 4.29, 'Carbohydrt_(g)': 37.14}
# {'_id': ObjectId('667fe0f54d235c4a249133e3'), 'NDB_No': 1239, 'Shrt_Desc': 'ICE CRM COOKIE SNDWCH', 'Water_(g)': 48.7, 'Energ_Kcal': 240, 'Protein_(g)': 3.7, 'Carbohydrt_(g)': 39.6}
# {'_id': ObjectId('667fe0f54d235c4a249133e4'), 'NDB_No': 1240, 'Shrt_Desc': 'ICE CRM CONE,CHOC COVERED,W/ NUTS,FLAVORS OTHER THAN CHOC', 'Water_(g)': 37.43, 'Energ_Kcal': 354, 'Protein_(g)': 5.21, 'Carbohydrt_(g)': 34.38}
# {'_id': ObjectId('667fe0f54d235c4a249133e5'), 'NDB_No': 1241, 'Shrt_Desc': 'ICE CRM SNDWCH,MADE W/ LT ICE CRM,VANILLA', 'Water_(g)': 52.63, 'Energ_Kcal': 186, 'Protein_(g)': 4.29, 'Carbohydrt_(g)': 39.64}
# {'_id': ObjectId('667fe0f54d235c4a249133e6'), 'NDB_No': 1242, 'Shrt_Desc': 'ICE CRM SNDWCH,VANILLA,LT,NO SUGAR ADDED', 'Water_(g)': 48.13, 'Energ_Kcal': 200, 'Protein_(g)': 5.71, 'Carbohydrt_(g)': 42.86}
# {'_id': ObjectId('667fe0f54d235c4a249133e7'), 'NDB_No': 1243, 'Shrt_Desc': 'FAT FREE ICE CRM,NO SUGAR ADDED,FLAVORS OTHER THAN CHOC', 'Water_(g)': 65.52, 'Energ_Kcal': 129, 'Protein_(g)': 4.41, 'Carbohydrt_(g)': 27.94}
# {'_id': ObjectId('667fe0f54d235c4a249133e8'), 'NDB_No': 1244, 'Shrt_Desc': 'MILK DSSRT BAR,FRZ,MADE FROM LOWFAT MILK', 'Water_(g)': 61.43, 'Energ_Kcal': 147, 'Protein_(g)': 4.41, 'Carbohydrt_(g)': 33.09}
# {'_id': ObjectId('667fe0f54d235c4a249133e9'), 'NDB_No': 1250, 'Shrt_Desc': 'NUTRITIONAL SUPP FOR PEOPLE W/ DIABETES,LIQ', 'Water_(g)': 79.74, 'Energ_Kcal': 88, 'Protein_(g)': 4.4, 'Carbohydrt_(g)': 11.88}
# {'_id': ObjectId('667fe0f54d235c4a249133ea'), 'NDB_No': 1251, 'Shrt_Desc': 'CHEESE,MEXICAN BLEND', 'Water_(g)': 42.48, 'Energ_Kcal': 358, 'Protein_(g)': 23.54, 'Carbohydrt_(g)': 1.75}
# {'_id': ObjectId('667fe0f54d235c4a249133eb'), 'NDB_No': 1252, 'Shrt_Desc': 'CHEESE PRODUCT,PAST PROCESS,AMERICAN,VITAMIN D FORT', 'Water_(g)': 45.07, 'Energ_Kcal': 307, 'Protein_(g)': 16.09, 'Carbohydrt_(g)': 8.85}
# {'_id': ObjectId('667fe0f54d235c4a249133ec'), 'NDB_No': 1253, 'Shrt_Desc': 'CHEESE,PAST PROCESS,AMERICAN,WO/ ADDED VITAMIN D', 'Water_(g)': 39.61, 'Energ_Kcal': 371, 'Protein_(g)': 18.13, 'Carbohydrt_(g)': 3.7}
# {'_id': ObjectId('667fe0f54d235c4a249133ed'), 'NDB_No': 1254, 'Shrt_Desc': 'CHEESE FD,PAST PROCESS,AMERICAN,WO/ ADDED VITAMIN D', 'Water_(g)': 44.0, 'Energ_Kcal': 330, 'Protein_(g)': 16.86, 'Carbohydrt_(g)': 8.56}
# {'_id': ObjectId('667fe0f54d235c4a249133ee'), 'NDB_No': 1255, 'Shrt_Desc': 'EGG,WHL,RAW,FRZ,SALTED,PAST', 'Water_(g)': 67.83, 'Energ_Kcal': 138, 'Protein_(g)': 10.97, 'Carbohydrt_(g)': 0.83}
# {'_id': ObjectId('667fe0f54d235c4a249133ef'), 'NDB_No': 1256, 'Shrt_Desc': 'YOGURT,GREEK,PLN,NONFAT', 'Water_(g)': 85.1, 'Energ_Kcal': 59, 'Protein_(g)': 10.19, 'Carbohydrt_(g)': 3.6}
# {'_id': ObjectId('667fe0f54d235c4a249133f0'), 'NDB_No': 1258, 'Shrt_Desc': 'EGG,WHITE,DRIED,STABILIZED,GLUCOSE RED', 'Water_(g)': 5.48, 'Energ_Kcal': 357, 'Protein_(g)': 84.08, 'Carbohydrt_(g)': 4.51}
# {'_id': ObjectId('667fe0f54d235c4a249133f1'), 'NDB_No': 1259, 'Shrt_Desc': 'CHEESE SPRD,AMERICAN OR CHEDDAR CHS BASE,RED FAT', 'Water_(g)': 61.82, 'Energ_Kcal': 176, 'Protein_(g)': 13.41, 'Carbohydrt_(g)': 10.71}
# {'_id': ObjectId('667fe0f54d235c4a249133f2'), 'NDB_No': 1260, 'Shrt_Desc': 'CHEESE,CHEDDAR,RED FAT', 'Water_(g)': 44.29, 'Energ_Kcal': 309, 'Protein_(g)': 27.35, 'Carbohydrt_(g)': 4.06}
# {'_id': ObjectId('667fe0f54d235c4a249133f3'), 'NDB_No': 1263, 'Shrt_Desc': 'ICE CRM,LT,SOFT SERVE,CHOC', 'Water_(g)': 68.92, 'Energ_Kcal': 141, 'Protein_(g)': 3.36, 'Carbohydrt_(g)': 23.15}
# {'_id': ObjectId('667fe0f54d235c4a249133f4'), 'NDB_No': 1264, 'Shrt_Desc': 'ICE CRM BAR,STK OR NUGGET,W/ CRUNCH COATING', 'Water_(g)': 35.48, 'Energ_Kcal': 358, 'Protein_(g)': 2.11, 'Carbohydrt_(g)': 37.12}
# {'_id': ObjectId('667fe0f54d235c4a249133f5'), 'NDB_No': 1265, 'Shrt_Desc': 'CHEESE,CHEDDAR,NONFAT OR FAT FREE', 'Water_(g)': 57.0, 'Energ_Kcal': 157, 'Protein_(g)': 32.14, 'Carbohydrt_(g)': 7.14}
# {'_id': ObjectId('667fe0f54d235c4a249133f6'), 'NDB_No': 1266, 'Shrt_Desc': 'CHEESE,SWISS,NONFAT OR FAT FREE', 'Water_(g)': 63.6, 'Energ_Kcal': 127, 'Protein_(g)': 28.4, 'Carbohydrt_(g)': 3.4}
# {'_id': ObjectId('667fe0f54d235c4a249133f7'), 'NDB_No': 1267, 'Shrt_Desc': 'CHEESE,MEXICAN,QUESO COTIJA', 'Water_(g)': 38.0, 'Energ_Kcal': 366, 'Protein_(g)': 20.0, 'Carbohydrt_(g)': 3.97}
# {'_id': ObjectId('667fe0f54d235c4a249133f8'), 'NDB_No': 1270, 'Shrt_Desc': 'CHEESE,CHEDDAR,SHARP,SLICED', 'Water_(g)': 36.15, 'Energ_Kcal': 410, 'Protein_(g)': 24.25, 'Carbohydrt_(g)': 2.13}
# {'_id': ObjectId('667fe0f54d235c4a249133f9'), 'NDB_No': 1271, 'Shrt_Desc': 'CHEESE,MOZZARELLA,LO MOIST,PART-SKIM,SHREDDED', 'Water_(g)': 44.81, 'Energ_Kcal': 304, 'Protein_(g)': 23.63, 'Carbohydrt_(g)': 8.06}
# {'_id': ObjectId('667fe0f54d235c4a249133fa'), 'NDB_No': 1275, 'Shrt_Desc': 'YOGURT,GREEK,NONFAT,VANILLA,CHOBANI', 'Water_(g)': 82.03, 'Energ_Kcal': 71, 'Protein_(g)': 9.07, 'Carbohydrt_(g)': 8.09}
# {'_id': ObjectId('667fe0f54d235c4a249133fb'), 'NDB_No': 1276, 'Shrt_Desc': 'YOGURT,GREEK,STRAWBERRY,DANNON OIKOS', 'Water_(g)': 76.6, 'Energ_Kcal': 106, 'Protein_(g)': 8.25, 'Carbohydrt_(g)': 11.67}
# {'_id': ObjectId('667fe0f54d235c4a249133fc'), 'NDB_No': 1278, 'Shrt_Desc': 'YOGURT,GREEK,NONFAT,VANILLA,DANNON OIKOS', 'Water_(g)': 78.5, 'Energ_Kcal': 85, 'Protein_(g)': 8.12, 'Carbohydrt_(g)': 12.72}
# {'_id': ObjectId('667fe0f54d235c4a249133fd'), 'NDB_No': 1280, 'Shrt_Desc': 'YOGURT,GREEK,NONFAT,STRAWBERRY,DANNON OIKOS', 'Water_(g)': 78.63, 'Energ_Kcal': 84, 'Protein_(g)': 8.03, 'Carbohydrt_(g)': 12.53}
# {'_id': ObjectId('667fe0f54d235c4a249133fe'), 'NDB_No': 1281, 'Shrt_Desc': 'YOGURT,GREEK,NONFAT,STRAWBERRY,CHOBANI', 'Water_(g)': 79.62, 'Energ_Kcal': 80, 'Protein_(g)': 8.03, 'Carbohydrt_(g)': 11.62}
# {'_id': ObjectId('667fe0f54d235c4a249133ff'), 'NDB_No': 1284, 'Shrt_Desc': 'YOGURT,GREEK,STRAWBERRY,LOWFAT', 'Water_(g)': 76.81, 'Energ_Kcal': 103, 'Protein_(g)': 8.17, 'Carbohydrt_(g)': 11.89}
# {'_id': ObjectId('667fe0f54d235c4a24913400'), 'NDB_No': 1285, 'Shrt_Desc': 'YOGURT,GREEK,STRAWBERRY,NONFAT', 'Water_(g)': 79.13, 'Energ_Kcal': 82, 'Protein_(g)': 8.05, 'Carbohydrt_(g)': 12.07}
# {'_id': ObjectId('667fe0f54d235c4a24913401'), 'NDB_No': 1286, 'Shrt_Desc': 'YOGURT,GREEK,VANILLA,NONFAT', 'Water_(g)': 80.26, 'Energ_Kcal': 78, 'Protein_(g)': 8.64, 'Carbohydrt_(g)': 10.37}
# {'_id': ObjectId('667fe0f54d235c4a24913402'), 'NDB_No': 1287, 'Shrt_Desc': 'YOGURT,GREEK,PLN,LOWFAT', 'Water_(g)': 83.56, 'Energ_Kcal': 73, 'Protein_(g)': 9.95, 'Carbohydrt_(g)': 3.94}
# {'_id': ObjectId('667fe0f54d235c4a24913403'), 'NDB_No': 1289, 'Shrt_Desc': 'KEFIR,LOWFAT,PLN,LIFEWAY', 'Water_(g)': 90.07, 'Energ_Kcal': 41, 'Protein_(g)': 3.79, 'Carbohydrt_(g)': 4.48}
# {'_id': ObjectId('667fe0f54d235c4a24913404'), 'NDB_No': 1290, 'Shrt_Desc': 'KEFIR,LOWFAT,STRAWBERRY,LIFEWAY', 'Water_(g)': 84.82, 'Energ_Kcal': 62, 'Protein_(g)': 3.39, 'Carbohydrt_(g)': 10.2}
# {'_id': ObjectId('667fe0f54d235c4a24913405'), 'NDB_No': 1291, 'Shrt_Desc': 'MILK,CND,EVAP,WO/ VIT A', 'Water_(g)': 74.04, 'Energ_Kcal': 107, 'Protein_(g)': 6.67, 'Carbohydrt_(g)': 15.74}
# {'_id': ObjectId('667fe0f54d235c4a24913406'), 'NDB_No': 1292, 'Shrt_Desc': 'MILK,CHOC,FAT FREE,W/ ADDED VIT A & VITAMIN D', 'Water_(g)': 82.34, 'Energ_Kcal': 67, 'Protein_(g)': 3.39, 'Carbohydrt_(g)': 13.46}
# {'_id': ObjectId('667fe0f54d235c4a24913407'), 'NDB_No': 1293, 'Shrt_Desc': 'YOGURT,GREEK,PLN,WHL MILK', 'Water_(g)': 81.3, 'Energ_Kcal': 97, 'Protein_(g)': 9.0, 'Carbohydrt_(g)': 3.98}
# {'_id': ObjectId('667fe0f54d235c4a24913408'), 'NDB_No': 1294, 'Shrt_Desc': 'YOGURT,GREEK,FRUIT,WHL MILK', 'Water_(g)': 76.81, 'Energ_Kcal': 106, 'Protein_(g)': 7.33, 'Carbohydrt_(g)': 12.29}
# {'_id': ObjectId('667fe0f54d235c4a24913409'), 'NDB_No': 1295, 'Shrt_Desc': 'YOGURT,VANILLA,NON-FAT', 'Water_(g)': 79.0, 'Energ_Kcal': 78, 'Protein_(g)': 2.94, 'Carbohydrt_(g)': 17.04}
# {'_id': ObjectId('667fe0f54d235c4a2491340a'), 'NDB_No': 1297, 'Shrt_Desc': 'YOGURT,GREEK,VANILLA,LOWFAT', 'Water_(g)': 78.76, 'Energ_Kcal': 95, 'Protein_(g)': 8.64, 'Carbohydrt_(g)': 9.54}
# {'_id': ObjectId('667fe0f54d235c4a2491340b'), 'NDB_No': 1298, 'Shrt_Desc': 'YOGURT,FRZ,FLAVORS OTHER THAN CHOC,LOWFAT', 'Water_(g)': 68.08, 'Energ_Kcal': 139, 'Protein_(g)': 8.0, 'Carbohydrt_(g)': 21.0}
# {'_id': ObjectId('667fe0f54d235c4a2491340c'), 'NDB_No': 1300, 'Shrt_Desc': 'ICE CRM BAR,COVERED W/ CHOC & NUTS', 'Water_(g)': 55.14, 'Energ_Kcal': 303, 'Protein_(g)': 5.62, 'Carbohydrt_(g)': 11.89}
# {'_id': ObjectId('667fe0f54d235c4a2491340d'), 'NDB_No': 1301, 'Shrt_Desc': 'ICE CRM SUNDAE CONE', 'Water_(g)': 53.31, 'Energ_Kcal': 254, 'Protein_(g)': 3.0, 'Carbohydrt_(g)': 28.89}
# {'_id': ObjectId('667fe0f54d235c4a2491340e'), 'NDB_No': 1302, 'Shrt_Desc': 'LIGHT ICE CRM,CREAMSICLE', 'Water_(g)': 61.77, 'Energ_Kcal': 165, 'Protein_(g)': 1.54, 'Carbohydrt_(g)': 32.75}
# ...
# {'_id': ObjectId('667fe0fb4d235c4a2491551c'), 'NDB_No': 43340, 'Shrt_Desc': 'CHEESE,PARMESAN,LO NA', 'Water_(g)': 22.2, 'Energ_Kcal': 451, 'Protein_(g)': 41.6, 'Carbohydrt_(g)': 3.7}
# {'_id': ObjectId('667fe0fb4d235c4a2491551d'), 'NDB_No': 43344, 'Shrt_Desc': 'JAMS,PRESERVES,MARMALADE,RED SUGAR', 'Water_(g)': 62.0, 'Energ_Kcal': 151, 'Protein_(g)': 0.0, 'Carbohydrt_(g)': 37.6}
# {'_id': ObjectId('667fe0fb4d235c4a2491551e'), 'NDB_No': 43345, 'Shrt_Desc': 'BEVER,FRUIT-FLAV DRK,PDR,W/ HI VIT C W/ OTHER ADD VIT,LO CAL', 'Water_(g)': 1.32, 'Energ_Kcal': 227, 'Protein_(g)': 0.25, 'Carbohydrt_(g)': 91.0}
# {'_id': ObjectId('667fe0fb4d235c4a2491551f'), 'NDB_No': 43346, 'Shrt_Desc': 'FROZEN NOVELTIES,JUC TYPE,ORANGE', 'Water_(g)': 76.1, 'Energ_Kcal': 95, 'Protein_(g)': 0.5, 'Carbohydrt_(g)': 23.17}
# {'_id': ObjectId('667fe0fb4d235c4a24915520'), 'NDB_No': 43352, 'Shrt_Desc': 'CHEESE,COTTAGE,LOWFAT,1% MILKFAT,NO NA', 'Water_(g)': 83.5, 'Energ_Kcal': 72, 'Protein_(g)': 12.4, 'Carbohydrt_(g)': 2.7}
# {'_id': ObjectId('667fe0fb4d235c4a24915521'), 'NDB_No': 43355, 'Shrt_Desc': 'MAYONNAISE,LO NA,LO CAL OR DIET', 'Water_(g)': 62.7, 'Energ_Kcal': 231, 'Protein_(g)': 0.3, 'Carbohydrt_(g)': 16.0}
# {'_id': ObjectId('667fe0fb4d235c4a24915522'), 'NDB_No': 43364, 'Shrt_Desc': 'SNACKS,TORTILLA CHIPS,UNSALTED,WHITE CORN', 'Water_(g)': 2.09, 'Energ_Kcal': 503, 'Protein_(g)': 7.79, 'Carbohydrt_(g)': 65.32}
# {'_id': ObjectId('667fe0fb4d235c4a24915523'), 'NDB_No': 43365, 'Shrt_Desc': 'TOMATO&VEG JUC,LO NA', 'Water_(g)': 93.5, 'Energ_Kcal': 22, 'Protein_(g)': 0.6, 'Carbohydrt_(g)': 4.59}
# {'_id': ObjectId('667fe0fb4d235c4a24915524'), 'NDB_No': 43366, 'Shrt_Desc': 'TURKEY,WING,SMOKED,CKD,W/SKN,BONE REMOVED', 'Water_(g)': 59.5, 'Energ_Kcal': 221, 'Protein_(g)': 27.4, 'Carbohydrt_(g)': 0.0}
# {'_id': ObjectId('667fe0fb4d235c4a24915525'), 'NDB_No': 43367, 'Shrt_Desc': 'TURKEY,DRUMSTK,SMOKED,CKD,W/SKN,BONE REMOVED', 'Water_(g)': 61.2, 'Energ_Kcal': 208, 'Protein_(g)': 27.9, 'Carbohydrt_(g)': 0.0}
# {'_id': ObjectId('667fe0fb4d235c4a24915526'), 'NDB_No': 43369, 'Shrt_Desc': 'BEVERAGES,CHOCOLATE-FLAVORED DRK,WHEY & MILK BSD', 'Water_(g)': 87.63, 'Energ_Kcal': 49, 'Protein_(g)': 0.64, 'Carbohydrt_(g)': 10.68}
# {'_id': ObjectId('667fe0fb4d235c4a24915527'), 'NDB_No': 43373, 'Shrt_Desc': 'BABYFOOD,DINNER,CHICK&NOODLE W/VEG,TODD', 'Water_(g)': 85.3, 'Energ_Kcal': 66, 'Protein_(g)': 3.8, 'Carbohydrt_(g)': 8.89}
# {'_id': ObjectId('667fe0fb4d235c4a24915528'), 'NDB_No': 43378, 'Shrt_Desc': 'PORK,CURED,BACON,CKD,BRLD,PAN-FRIED OR RSTD,RED NA', 'Water_(g)': 12.32, 'Energ_Kcal': 541, 'Protein_(g)': 37.04, 'Carbohydrt_(g)': 1.43}
# {'_id': ObjectId('667fe0fb4d235c4a24915529'), 'NDB_No': 43379, 'Shrt_Desc': 'CHEESE,PAST PROCESS,SWISS,LOFAT', 'Water_(g)': 59.1, 'Energ_Kcal': 165, 'Protein_(g)': 25.5, 'Carbohydrt_(g)': 4.3}
# {'_id': ObjectId('667fe0fb4d235c4a2491552a'), 'NDB_No': 43382, 'Shrt_Desc': 'CRANBERRY JUC,UNSWTND', 'Water_(g)': 87.13, 'Energ_Kcal': 46, 'Protein_(g)': 0.39, 'Carbohydrt_(g)': 12.2}
# {'_id': ObjectId('667fe0fb4d235c4a2491552b'), 'NDB_No': 43384, 'Shrt_Desc': 'BEEF,BOLOGNA,RED NA', 'Water_(g)': 54.8, 'Energ_Kcal': 310, 'Protein_(g)': 11.7, 'Carbohydrt_(g)': 2.0}
# {'_id': ObjectId('667fe0fb4d235c4a2491552c'), 'NDB_No': 43387, 'Shrt_Desc': 'TURNIP GRNS,CND,NO SALT', 'Water_(g)': 94.69, 'Energ_Kcal': 19, 'Protein_(g)': 1.36, 'Carbohydrt_(g)': 2.81}
# {'_id': ObjectId('667fe0fb4d235c4a2491552d'), 'NDB_No': 43390, 'Shrt_Desc': 'TURKEY,LT OR DK MEAT,SMOKED,CKD,W/SKN,BONE REMOVED', 'Water_(g)': 61.7, 'Energ_Kcal': 208, 'Protein_(g)': 28.1, 'Carbohydrt_(g)': 0.0}
# {'_id': ObjectId('667fe0fb4d235c4a2491552e'), 'NDB_No': 43391, 'Shrt_Desc': 'TURKEY,LT OR DK MEAT,SMOKED,CKD,SKN & BONE REMOVED', 'Water_(g)': 64.9, 'Energ_Kcal': 170, 'Protein_(g)': 29.3, 'Carbohydrt_(g)': 0.0}
# {'_id': ObjectId('667fe0fb4d235c4a2491552f'), 'NDB_No': 43392, 'Shrt_Desc': 'HEARTS OF PALM,RAW', 'Water_(g)': 69.5, 'Energ_Kcal': 115, 'Protein_(g)': 2.7, 'Carbohydrt_(g)': 25.61}
# {'_id': ObjectId('667fe0fb4d235c4a24915530'), 'NDB_No': 43393, 'Shrt_Desc': "CEREALS RTE,POST,SHREDDED WHEAT N' BRAN,SPOON-SIZE", 'Water_(g)': 3.14, 'Energ_Kcal': 339, 'Protein_(g)': 10.93, 'Carbohydrt_(g)': 80.65}
# {'_id': ObjectId('667fe0fb4d235c4a24915531'), 'NDB_No': 43396, 'Shrt_Desc': 'CHEESE,COTTAGE,LOWFAT,1% MILKFAT,W/VEG', 'Water_(g)': 83.5, 'Energ_Kcal': 67, 'Protein_(g)': 10.9, 'Carbohydrt_(g)': 3.0}
# {'_id': ObjectId('667fe0fb4d235c4a24915532'), 'NDB_No': 43398, 'Shrt_Desc': 'CHEESE,PAST PROCESS,CHEDDAR OR AMERICAN,LO NA', 'Water_(g)': 42.8, 'Energ_Kcal': 376, 'Protein_(g)': 22.2, 'Carbohydrt_(g)': 1.6}
# {'_id': ObjectId('667fe0fb4d235c4a24915533'), 'NDB_No': 43401, 'Shrt_Desc': 'BEVERAGES,COFFEE,INST,W/ WHTNR,RED CAL', 'Water_(g)': 6.16, 'Energ_Kcal': 509, 'Protein_(g)': 1.96, 'Carbohydrt_(g)': 59.94}
# {'_id': ObjectId('667fe0fb4d235c4a24915534'), 'NDB_No': 43404, 'Shrt_Desc': 'BEVERAGES,CRANBERRY-APPLE JUC DRK,LO CAL,W/ VIT C ADDED', 'Water_(g)': 95.2, 'Energ_Kcal': 19, 'Protein_(g)': 0.1, 'Carbohydrt_(g)': 4.7}
# {'_id': ObjectId('667fe0fb4d235c4a24915535'), 'NDB_No': 43405, 'Shrt_Desc': 'CHEESE,SWISS,LOW SODIUM', 'Water_(g)': 37.8, 'Energ_Kcal': 374, 'Protein_(g)': 28.4, 'Carbohydrt_(g)': 3.4}
# {'_id': ObjectId('667fe0fb4d235c4a24915536'), 'NDB_No': 43406, 'Shrt_Desc': 'YEAST EXTRACT SPREAD', 'Water_(g)': 40.9, 'Energ_Kcal': 185, 'Protein_(g)': 23.88, 'Carbohydrt_(g)': 20.42}
# {'_id': ObjectId('667fe0fb4d235c4a24915537'), 'NDB_No': 43408, 'Shrt_Desc': 'BABYFOOD,JUICE,PEAR', 'Water_(g)': 87.9, 'Energ_Kcal': 47, 'Protein_(g)': 0.0, 'Carbohydrt_(g)': 11.86}
# {'_id': ObjectId('667fe0fb4d235c4a24915538'), 'NDB_No': 43410, 'Shrt_Desc': 'CHICKEN,MEATLESS,BREADED,FRIED', 'Water_(g)': 56.44, 'Energ_Kcal': 234, 'Protein_(g)': 21.28, 'Carbohydrt_(g)': 8.51}
# {'_id': ObjectId('667fe0fb4d235c4a24915539'), 'NDB_No': 43417, 'Shrt_Desc': 'BABYFOOD,MEAT,BF W/ VEG,TODD', 'Water_(g)': 85.23, 'Energ_Kcal': 68, 'Protein_(g)': 3.5, 'Carbohydrt_(g)': 8.72}
# {'_id': ObjectId('667fe0fb4d235c4a2491553a'), 'NDB_No': 43432, 'Shrt_Desc': 'BABYFOOD,DINNER,MACARONI,BF&TOMATO SAU,TODD', 'Water_(g)': 81.81, 'Energ_Kcal': 81, 'Protein_(g)': 4.34, 'Carbohydrt_(g)': 11.53}
# {'_id': ObjectId('667fe0fb4d235c4a2491553b'), 'NDB_No': 43441, 'Shrt_Desc': 'ROLLS,PUMPERNICKEL', 'Water_(g)': 32.0, 'Energ_Kcal': 276, 'Protein_(g)': 10.8, 'Carbohydrt_(g)': 51.87}
# {'_id': ObjectId('667fe0fb4d235c4a2491553c'), 'NDB_No': 43447, 'Shrt_Desc': 'SNACKS,CORN-BASED,EXTRUDED,CHIPS,UNSALTED', 'Water_(g)': 1.0, 'Energ_Kcal': 557, 'Protein_(g)': 6.6, 'Carbohydrt_(g)': 57.4}
# {'_id': ObjectId('667fe0fb4d235c4a2491553d'), 'NDB_No': 43449, 'Shrt_Desc': 'BEANS,BKD,CND,NO SALT ADDED', 'Water_(g)': 72.6, 'Energ_Kcal': 105, 'Protein_(g)': 4.8, 'Carbohydrt_(g)': 20.49}
# {'_id': ObjectId('667fe0fb4d235c4a2491553e'), 'NDB_No': 43450, 'Shrt_Desc': 'FROZEN NOVELTIES,JUC TYPE,JUC W/ CRM', 'Water_(g)': 72.57, 'Energ_Kcal': 115, 'Protein_(g)': 1.41, 'Carbohydrt_(g)': 24.11}
# {'_id': ObjectId('667fe0fb4d235c4a2491553f'), 'NDB_No': 43476, 'Shrt_Desc': 'TOFU YOGURT', 'Water_(g)': 77.5, 'Energ_Kcal': 94, 'Protein_(g)': 3.5, 'Carbohydrt_(g)': 15.96}
# {'_id': ObjectId('667fe0fb4d235c4a24915540'), 'NDB_No': 43479, 'Shrt_Desc': 'ALCOHOLIC BEV,RICE (SAKE)', 'Water_(g)': 78.4, 'Energ_Kcal': 134, 'Protein_(g)': 0.5, 'Carbohydrt_(g)': 5.0}
# {'_id': ObjectId('667fe0fb4d235c4a24915541'), 'NDB_No': 43483, 'Shrt_Desc': 'MILLET,PUFFED', 'Water_(g)': 2.5, 'Energ_Kcal': 354, 'Protein_(g)': 13.0, 'Carbohydrt_(g)': 80.0}
# {'_id': ObjectId('667fe0fb4d235c4a24915542'), 'NDB_No': 43495, 'Shrt_Desc': 'CEREALS RTE,OAT BRAN FLAKES,HEALTH VALLEY', 'Water_(g)': 3.4, 'Energ_Kcal': 380, 'Protein_(g)': 10.0, 'Carbohydrt_(g)': 78.0}
# {'_id': ObjectId('667fe0fb4d235c4a24915543'), 'NDB_No': 43497, 'Shrt_Desc': 'JELLYFISH,DRIED,SALTED', 'Water_(g)': 68.0, 'Energ_Kcal': 36, 'Protein_(g)': 5.5, 'Carbohydrt_(g)': 0.0}
# {'_id': ObjectId('667fe0fb4d235c4a24915544'), 'NDB_No': 43506, 'Shrt_Desc': 'ICE CRM BAR,CHOC OR CARAMEL COVERED,W/NUTS', 'Water_(g)': 43.1, 'Energ_Kcal': 323, 'Protein_(g)': 4.4, 'Carbohydrt_(g)': 30.9}
# {'_id': ObjectId('667fe0fb4d235c4a24915545'), 'NDB_No': 43507, 'Shrt_Desc': 'FRANKFURTER,LO NA', 'Water_(g)': 56.7, 'Energ_Kcal': 312, 'Protein_(g)': 12.0, 'Carbohydrt_(g)': 1.8}
# {'_id': ObjectId('667fe0fb4d235c4a24915546'), 'NDB_No': 43514, 'Shrt_Desc': 'FROZEN NOVELTIES,ICE TYPE,POP,W/ LO CAL SWTNR', 'Water_(g)': 94.03, 'Energ_Kcal': 24, 'Protein_(g)': 0.0, 'Carbohydrt_(g)': 5.92}
# {'_id': ObjectId('667fe0fb4d235c4a24915547'), 'NDB_No': 43523, 'Shrt_Desc': 'BABYFOOD,MXD FRUIT YOGURT,STR', 'Water_(g)': 81.8, 'Energ_Kcal': 75, 'Protein_(g)': 0.8, 'Carbohydrt_(g)': 16.23}
# {'_id': ObjectId('667fe0fb4d235c4a24915548'), 'NDB_No': 43528, 'Shrt_Desc': 'BEVERAGES,ABBOTT,ENSURE PLUS,RTD', 'Water_(g)': 69.84, 'Energ_Kcal': 141, 'Protein_(g)': 5.16, 'Carbohydrt_(g)': 19.88}
# {'_id': ObjectId('667fe0fb4d235c4a24915549'), 'NDB_No': 43529, 'Shrt_Desc': 'BABYFOOD,RICE&APPLS,DRY', 'Water_(g)': 3.2, 'Energ_Kcal': 396, 'Protein_(g)': 6.7, 'Carbohydrt_(g)': 86.89}
# {'_id': ObjectId('667fe0fb4d235c4a2491554a'), 'NDB_No': 43535, 'Shrt_Desc': 'BABYFOOD,JUC,APPL - CHERRY', 'Water_(g)': 88.2, 'Energ_Kcal': 47, 'Protein_(g)': 0.2, 'Carbohydrt_(g)': 11.2}
# {'_id': ObjectId('667fe0fb4d235c4a2491554b'), 'NDB_No': 43536, 'Shrt_Desc': 'BABYFOOD,DSSRT,PEACH YOGURT', 'Water_(g)': 80.87, 'Energ_Kcal': 76, 'Protein_(g)': 0.9, 'Carbohydrt_(g)': 17.6}
# {'_id': ObjectId('667fe0fb4d235c4a2491554c'), 'NDB_No': 43537, 'Shrt_Desc': 'BABYFOOD,DSSRT,BLUEBERRY YOGURT,STR', 'Water_(g)': 81.4, 'Energ_Kcal': 77, 'Protein_(g)': 0.5, 'Carbohydrt_(g)': 17.05}
# {'_id': ObjectId('667fe0fb4d235c4a2491554d'), 'NDB_No': 43539, 'Shrt_Desc': 'BABYFOOD,DSSRT,BANANA YOGURT,STR', 'Water_(g)': 80.7, 'Energ_Kcal': 78, 'Protein_(g)': 1.1, 'Carbohydrt_(g)': 17.35}
# {'_id': ObjectId('667fe0fb4d235c4a2491554e'), 'NDB_No': 43541, 'Shrt_Desc': 'ICE CREAMS,CHOC,RICH', 'Water_(g)': 57.52, 'Energ_Kcal': 251, 'Protein_(g)': 4.72, 'Carbohydrt_(g)': 19.78}
# {'_id': ObjectId('667fe0fb4d235c4a2491554f'), 'NDB_No': 43543, 'Shrt_Desc': 'MILK,IMITATION,NON-SOY', 'Water_(g)': 90.0, 'Energ_Kcal': 46, 'Protein_(g)': 1.6, 'Carbohydrt_(g)': 5.3}
# {'_id': ObjectId('667fe0fb4d235c4a24915550'), 'NDB_No': 43544, 'Shrt_Desc': 'BABYFOOD,CRL,RICE W/ PEARS & APPL,DRY,INST FORT', 'Water_(g)': 2.0, 'Energ_Kcal': 389, 'Protein_(g)': 6.6, 'Carbohydrt_(g)': 88.5}
# {'_id': ObjectId('667fe0fb4d235c4a24915551'), 'NDB_No': 43546, 'Shrt_Desc': 'BABYFOOD,BANANA NO TAPIOCA,STR', 'Water_(g)': 76.7, 'Energ_Kcal': 91, 'Protein_(g)': 1.0, 'Carbohydrt_(g)': 21.34}
# {'_id': ObjectId('667fe0fb4d235c4a24915552'), 'NDB_No': 43550, 'Shrt_Desc': 'BABYFOOD,BANANA APPL DSSRT,STR', 'Water_(g)': 83.1, 'Energ_Kcal': 68, 'Protein_(g)': 0.3, 'Carbohydrt_(g)': 16.3}
# {'_id': ObjectId('667fe0fb4d235c4a24915553'), 'NDB_No': 43566, 'Shrt_Desc': 'SNACKS,TORTILLA CHIPS,LT (BAKED W/ LESS OIL)', 'Water_(g)': 1.3, 'Energ_Kcal': 465, 'Protein_(g)': 8.7, 'Carbohydrt_(g)': 73.4}
# {'_id': ObjectId('667fe0fb4d235c4a24915554'), 'NDB_No': 43570, 'Shrt_Desc': 'CEREALS RTE,POST,HONEY BUNCHES OF OATS,HONEY RSTD', 'Water_(g)': 5.0, 'Energ_Kcal': 401, 'Protein_(g)': 7.12, 'Carbohydrt_(g)': 81.19}
# {'_id': ObjectId('667fe0fb4d235c4a24915555'), 'NDB_No': 43572, 'Shrt_Desc': 'POPCORN,MICROWAVE,LOFAT&NA', 'Water_(g)': 2.8, 'Energ_Kcal': 429, 'Protein_(g)': 12.6, 'Carbohydrt_(g)': 73.39}
# {'_id': ObjectId('667fe0fb4d235c4a24915556'), 'NDB_No': 43585, 'Shrt_Desc': 'BABYFOOD,FRUIT SUPREME DSSRT', 'Water_(g)': 81.6, 'Energ_Kcal': 73, 'Protein_(g)': 0.5, 'Carbohydrt_(g)': 17.18}
# {'_id': ObjectId('667fe0fb4d235c4a24915557'), 'NDB_No': 43589, 'Shrt_Desc': 'CHEESE,SWISS,LOW FAT', 'Water_(g)': 59.6, 'Energ_Kcal': 179, 'Protein_(g)': 28.4, 'Carbohydrt_(g)': 3.4}
# {'_id': ObjectId('667fe0fb4d235c4a24915558'), 'NDB_No': 43595, 'Shrt_Desc': 'BREAKFAST BAR,CORN FLAKE CRUST W/FRUIT', 'Water_(g)': 14.5, 'Energ_Kcal': 377, 'Protein_(g)': 4.4, 'Carbohydrt_(g)': 72.9}
# {'_id': ObjectId('667fe0fb4d235c4a24915559'), 'NDB_No': 43597, 'Shrt_Desc': 'CHEESE,MOZZARELLA,LO NA', 'Water_(g)': 49.9, 'Energ_Kcal': 280, 'Protein_(g)': 27.5, 'Carbohydrt_(g)': 3.1}
# {'_id': ObjectId('667fe0fb4d235c4a2491555a'), 'NDB_No': 43598, 'Shrt_Desc': 'MAYONNAISE DRSNG,NO CHOL', 'Water_(g)': 21.7, 'Energ_Kcal': 688, 'Protein_(g)': 0.0, 'Carbohydrt_(g)': 0.3}
# {'_id': ObjectId('667fe0fb4d235c4a2491555b'), 'NDB_No': 44005, 'Shrt_Desc': 'OIL,CORN,PEANUT,AND OLIVE', 'Water_(g)': 0.0, 'Energ_Kcal': 884, 'Protein_(g)': 0.0, 'Carbohydrt_(g)': 0.0}
# {'_id': ObjectId('667fe0fb4d235c4a2491555c'), 'NDB_No': 44018, 'Shrt_Desc': 'SWEETENERS,TABLETOP,FRUCTOSE,LIQ', 'Water_(g)': 23.9, 'Energ_Kcal': 279, 'Protein_(g)': 0.0, 'Carbohydrt_(g)': 76.1}
# {'_id': ObjectId('667fe0fb4d235c4a2491555d'), 'NDB_No': 44048, 'Shrt_Desc': 'CHEESE FOOD,IMITATION', 'Water_(g)': 55.5, 'Energ_Kcal': 257, 'Protein_(g)': 4.08, 'Carbohydrt_(g)': 16.18}
# {'_id': ObjectId('667fe0fb4d235c4a2491555e'), 'NDB_No': 44055, 'Shrt_Desc': 'CELERY FLAKES,DRIED', 'Water_(g)': 9.0, 'Energ_Kcal': 319, 'Protein_(g)': 11.3, 'Carbohydrt_(g)': 63.7}
# {'_id': ObjectId('667fe0fb4d235c4a2491555f'), 'NDB_No': 44061, 'Shrt_Desc': 'PUDDINGS,CHOC FLAVOR,LO CAL,INST,DRY MIX', 'Water_(g)': 4.2, 'Energ_Kcal': 356, 'Protein_(g)': 5.3, 'Carbohydrt_(g)': 78.2}
# {'_id': ObjectId('667fe0fb4d235c4a24915560'), 'NDB_No': 44074, 'Shrt_Desc': 'BABYFOOD,GRAPE JUC,NO SUGAR,CND', 'Water_(g)': 84.4, 'Energ_Kcal': 62, 'Protein_(g)': 0.0, 'Carbohydrt_(g)': 15.38}
# {'_id': ObjectId('667fe0fb4d235c4a24915561'), 'NDB_No': 44110, 'Shrt_Desc': 'JELLIES,RED SUGAR,HOME PRESERVED', 'Water_(g)': 53.0, 'Energ_Kcal': 179, 'Protein_(g)': 0.3, 'Carbohydrt_(g)': 46.1}
# {'_id': ObjectId('667fe0fb4d235c4a24915562'), 'NDB_No': 44158, 'Shrt_Desc': 'PIE FILLINGS,BLUEBERRY,CND', 'Water_(g)': 54.66, 'Energ_Kcal': 181, 'Protein_(g)': 0.41, 'Carbohydrt_(g)': 44.38}
# {'_id': ObjectId('667fe0fb4d235c4a24915563'), 'NDB_No': 44203, 'Shrt_Desc': 'BEVERAGES,COCKTAIL MIX,NON-ALCOHOLIC,CONCD,FRZ', 'Water_(g)': 28.24, 'Energ_Kcal': 287, 'Protein_(g)': 0.08, 'Carbohydrt_(g)': 71.6}
# {'_id': ObjectId('667fe0fb4d235c4a24915564'), 'NDB_No': 44258, 'Shrt_Desc': 'PUDDINGS,CHOC FLAVOR,LO CAL,REG,DRY MIX', 'Water_(g)': 6.8, 'Energ_Kcal': 365, 'Protein_(g)': 10.08, 'Carbohydrt_(g)': 74.42}
# {'_id': ObjectId('667fe0fb4d235c4a24915565'), 'NDB_No': 44259, 'Shrt_Desc': 'PUDDINGS,ALL FLAVORS XCPT CHOC,LO CAL,REG,DRY MIX', 'Water_(g)': 10.4, 'Energ_Kcal': 351, 'Protein_(g)': 1.6, 'Carbohydrt_(g)': 86.04}
# {'_id': ObjectId('667fe0fb4d235c4a24915566'), 'NDB_No': 44260, 'Shrt_Desc': 'PUDDINGS,ALL FLAVORS XCPT CHOC,LO CAL,INST,DRY MIX', 'Water_(g)': 6.84, 'Energ_Kcal': 350, 'Protein_(g)': 0.81, 'Carbohydrt_(g)': 84.66}
# {'_id': ObjectId('667fe0fb4d235c4a24915567'), 'NDB_No': 48052, 'Shrt_Desc': 'VITAL WHEAT GLUTEN', 'Water_(g)': 8.2, 'Energ_Kcal': 370, 'Protein_(g)': 75.16, 'Carbohydrt_(g)': 13.79}
# {'_id': ObjectId('667fe0fb4d235c4a24915568'), 'NDB_No': 80200, 'Shrt_Desc': 'FROG LEGS,RAW', 'Water_(g)': 81.9, 'Energ_Kcal': 73, 'Protein_(g)': 16.4, 'Carbohydrt_(g)': 0.0}
# {'_id': ObjectId('667fe0fb4d235c4a24915569'), 'NDB_No': 83110, 'Shrt_Desc': 'MACKEREL,SALTED', 'Water_(g)': 43.0, 'Energ_Kcal': 305, 'Protein_(g)': 18.5, 'Carbohydrt_(g)': 0.0}
# {'_id': ObjectId('667fe0fb4d235c4a2491556a'), 'NDB_No': 90240, 'Shrt_Desc': 'SCALLOP,(BAY&SEA),CKD,STMD', 'Water_(g)': 70.25, 'Energ_Kcal': 111, 'Protein_(g)': 20.54, 'Carbohydrt_(g)': 5.41}
# {'_id': ObjectId('667fe0fb4d235c4a2491556b'), 'NDB_No': 90480, 'Shrt_Desc': 'SYRUP,CANE', 'Water_(g)': 26.0, 'Energ_Kcal': 269, 'Protein_(g)': 0.0, 'Carbohydrt_(g)': 73.14}
# {'_id': ObjectId('667fe0fb4d235c4a2491556c'), 'NDB_No': 90560, 'Shrt_Desc': 'SNAIL,RAW', 'Water_(g)': 79.2, 'Energ_Kcal': 90, 'Protein_(g)': 16.1, 'Carbohydrt_(g)': 2.0}
# {'_id': ObjectId('667fe0fb4d235c4a2491556d'), 'NDB_No': 93600, 'Shrt_Desc': 'TURTLE,GREEN,RAW', 'Water_(g)': 78.5, 'Energ_Kcal': 89, 'Protein_(g)': 19.8, 'Carbohydrt_(g)': 0.0}
